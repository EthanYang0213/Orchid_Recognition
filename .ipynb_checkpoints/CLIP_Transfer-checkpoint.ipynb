# %%
import os
import clip
import torch
from PIL import Image
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision.datasets import CIFAR100
from torch.utils.data import Subset
from tqdm import tqdm
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import random
from sklearn.model_selection import train_test_split, GridSearchCV

print(f'{torch.__version__}')



# 深度學習函式庫
import tensorflow
import tensorflow.keras as keras
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, Activation, BatchNormalization
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
print(f'{tensorflow.__version__}')
tensorflow.config.experimental_run_functions_eagerly = False
# Out:
# 1.7.1
# 2.4.0

# %%
csv_path = '../label.csv'
img_root = '../training'

# %%
# CLIP preprocess

# %%
# Data augmentation
train_transform = transforms.Compose([
    transforms.Resize((256, 256), interpolation=Image.BICUBIC),
    transforms.RandomCrop((224, 224)),
#     transforms.RandomApply([transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.0)], p=0.5),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply([transforms.RandomRotation(30)], p=0.5),
    transforms.ToTensor(), # 轉為torch tensor並歸一化
    transforms.Normalize(mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711]),
])
val_transform = transforms.Compose([
    transforms.Resize((256, 256), interpolation=Image.BICUBIC),
    transforms.RandomCrop((224, 224)),
#     transforms.RandomApply([transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05)], p=0.5),
#     transforms.RandomHorizontalFlip(p=0.5),
#     transforms.RandomVerticalFlip(p=0.5),
#     transforms.RandomApply([transforms.RandomRotation(30)], p=0.5),
    transforms.ToTensor(), # 轉為torch tensor並歸一化
    transforms.Normalize(mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711]),
])

# %%
# 若沒有使用外部transform, 則需要自己將feature和label轉為torch.tensor
# 要注意pytorch的影像格式是(3, 224, 224), 跟其他不一樣
# 圖片照類別分在不同資料夾, 因此CSV中的檔名已經是完整路徑
class CustomDatasetFromImages(Dataset):
    def __init__(self, csv_path, img_root, transform=None, target_transform=None, repeat=None):
        """
        Args:
            csv_path (string): path to csv file
            img_path (string): path to the folder where images are
            transform: pytorch transforms for transforms and tensor conversion
        """
        # Transforms
        self.transform = transform
        # Target_transform
        self.target_transform = target_transform
        # Read the csv file
        self.data_info = pd.read_csv(csv_path)
        # First column contains the image paths
        self.image_arr = np.asarray(self.data_info.iloc[:, 0])
        # Second column is the labels
        self.label_arr = np.asarray(self.data_info.iloc[:, 1])
        # Repeat for data augmentation
        self.repeat = repeat
        
        # Calculate len
        self.len = len(self.data_info.index)


    def __getitem__(self, i):
        iter_num = (i // self.len) + 1
        index = (i % self.len)
#         print("iters={},index={}".format(iter_num, index))
        # Get image name from the pandas df
        single_image_name = self.image_arr[index]
        single_image_name = os.path.join(img_root, single_image_name) # csv檔名若已經是完整路徑, 不用再加
        # Open image
        img = Image.open(single_image_name).convert('RGB') # 讀檔時轉為RGB
        
        # If there is an transform
        if self.transform:
            img = self.transform(img)
#         if self.target_transform:
#             label = self.target_transform(label)
        
        # Transform image to tensor
#         img_as_tensor = self.to_tensor(img_as_img)
        # Get label(class) of the image based on the cropped pandas column
        single_image_label = self.label_arr[index]

        return (img, single_image_label)

    def __len__(self):
        if self.repeat == None:
            self.data_len = 10000000 # 設定成無限迴圈生成資料,以num_epoc和max_iteration來決定跳出
        else:
            self.data_len = self.len * self.repeat
        return self.data_len

# %%
# Linear Probe 只用image-encoder, 沒用到text-encoder
def get_features(dataset, epoch_num=1):
    all_features = []
    all_labels = []
    epoch_num = epoch_num #總樣本迴圈次數
    batch_size = 100 
    train_data_nums = dataset.len
    max_iterate = int((train_data_nums+batch_size-1)/batch_size*epoch_num) #總迭代次數
    
    
    with torch.no_grad():
        for steps, (images, labels) in tqdm(enumerate(DataLoader(dataset, batch_size=batch_size))):
            features = model.encode_image(images.to(device))
            print(f'Steps: {steps}')
            all_features.append(features)
            all_labels.append(labels)
            
            if (steps+1) == max_iterate:
                break

    return torch.cat(all_features).cpu().numpy(), torch.cat(all_labels).cpu().numpy()

# %%
# Load the model, 可改其他model
device = "cuda" if torch.cuda.is_available() else "cpu"
# model, preprocess = clip.load('ViT-B/32', device)
model, preprocess = clip.load('ViT-L/14', device)

# %%
# Call dataset
# dataset =  CustomDatasetFromImages(csv_path=csv_path, img_root=img_root, transform=preprocess)
dataset =  CustomDatasetFromImages(csv_path=csv_path, img_root=img_root)

# %%
# 在Data augmentation前要先切好train-test
# 依照label比例分割, 讓train和val中各類別比例一樣
#Split dataset into train and validation

class CustomSubset(Subset):
    '''A custom subset class with customizable data transformation'''
    def __init__(self, dataset, indices, subset_transform=None, repeat=None):
        super().__init__(dataset, indices)
#         self.targets = dataset.targets
#         self.classes = dataset.classes
        self.subset_transform = subset_transform
        self.repeat = repeat
        self.len = len(indices)
 
    def __getitem__(self, i):
        index = (i % self.len)
        x, y = self.dataset[self.indices[index]]
        
        if self.subset_transform:
            x = self.subset_transform(x)
      
        return x, y   
    
    def __len__(self): 
        if self.repeat == None: # trainset
            self.subdata_len = 10000000 # 設定成無限迴圈生成資料,以num_epoc和max_iteration來決定跳出
        else: # val/test set
            self.subdata_len = self.len * self.repeat
        return self.subdata_len

train_indices, val_indices = train_test_split(list(range(len(dataset.label_arr))), test_size=0.3, stratify=dataset.label_arr, random_state=0)
train_dataset = CustomSubset(dataset, train_indices, repeat=None)
val_dataset = CustomSubset(dataset, val_indices, repeat=1)
# 設定train/val各自的preprocess
train_dataset.subset_transform = train_transform
val_dataset.subset_transform = val_transform
# train_dataset.subset_transform = preprocess
# val_dataset.subset_transform = preprocess

# %%
# 測試讀取dataset中資料
cnt = 0
for image, label in DataLoader(train_dataset, batch_size=1):
    print(label)
    img = image[0]
    img = img.numpy()
    img = np.transpose(img, (1, 2, 0))
    plt.imshow(img)
    plt.show()
    cnt += 1
    if cnt == 5:
        break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([55])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([111])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([64])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([194])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([47])

# %%
import time
# Calculate the image features
start = time.time()
train_features, train_labels = get_features(train_dataset, epoch_num=10)
val_features, val_labels = get_features(val_dataset, epoch_num=1)
end = time.time()
print(f'Time: {end-start}')
# Out:
# 1it [00:10, 10.58s/it]
# Steps: 0
# 2it [00:14,  6.57s/it]
# Steps: 1
# 3it [00:17,  4.98s/it]
# Steps: 2
# 4it [00:20,  4.12s/it]
# Steps: 3
# 5it [00:23,  3.80s/it]
# Steps: 4
# 6it [00:26,  3.61s/it]
# Steps: 5
# 7it [00:29,  3.47s/it]
# Steps: 6
# 8it [00:33,  3.37s/it]
# Steps: 7
# 9it [00:36,  3.30s/it]
# Steps: 8
# 10it [00:39,  3.16s/it]
# Steps: 9
# 11it [00:42,  3.10s/it]
# Steps: 10
# 12it [00:44,  3.07s/it]
# Steps: 11
# 13it [00:47,  2.93s/it]
# Steps: 12
# 14it [00:50,  2.81s/it]
# Steps: 13
# 15it [00:52,  2.74s/it]
# Steps: 14
# 16it [00:54,  2.48s/it]
# Steps: 15
# 17it [00:56,  2.18s/it]
# Steps: 16
# 18it [00:57,  1.97s/it]
# Steps: 17
# 19it [00:59,  1.82s/it]
# Steps: 18
# 20it [01:00,  1.71s/it]
# Steps: 19
# 21it [01:01,  1.64s/it]
# Steps: 20
# 22it [01:03,  1.59s/it]
# Steps: 21
# 23it [01:04,  1.56s/it]
# Steps: 22
# 24it [01:06,  1.53s/it]
# Steps: 23
# 25it [01:07,  1.52s/it]
# Steps: 24
# 26it [01:09,  1.52s/it]
# Steps: 25
# 27it [01:10,  1.51s/it]
# Steps: 26
# 28it [01:12,  1.50s/it]
# Steps: 27
# 29it [01:13,  1.50s/it]
# Steps: 28
# 30it [01:15,  1.49s/it]
# Steps: 29
# 31it [01:16,  1.49s/it]
# Steps: 30
# 32it [01:18,  1.48s/it]
# Steps: 31
# 33it [01:19,  1.49s/it]
# Steps: 32
# 34it [01:21,  1.49s/it]
# Steps: 33
# 35it [01:22,  1.49s/it]
# Steps: 34
# 36it [01:24,  1.48s/it]
# Steps: 35
# 37it [01:25,  1.48s/it]
# Steps: 36
# 38it [01:27,  1.48s/it]
# Steps: 37
# 39it [01:28,  1.48s/it]
# Steps: 38
# 40it [01:30,  1.47s/it]
# Steps: 39
# 41it [01:31,  1.48s/it]
# Steps: 40
# 42it [01:33,  1.48s/it]
# Steps: 41
# 43it [01:34,  1.48s/it]
# Steps: 42
# 44it [01:36,  1.48s/it]
# Steps: 43
# 45it [01:37,  1.49s/it]
# Steps: 44
# 46it [01:39,  1.48s/it]
# Steps: 45
# 47it [01:40,  1.48s/it]
# Steps: 46
# 48it [01:41,  1.49s/it]
# Steps: 47
# 49it [01:43,  1.49s/it]
# Steps: 48
# 50it [01:44,  1.49s/it]
# Steps: 49
# 51it [01:46,  1.48s/it]
# Steps: 50
# 52it [01:47,  1.48s/it]
# Steps: 51
# 53it [01:49,  1.50s/it]
# Steps: 52
# 54it [01:50,  1.51s/it]
# Steps: 53
# 55it [01:52,  1.49s/it]
# Steps: 54
# 56it [01:53,  1.49s/it]
# Steps: 55
# 57it [01:55,  1.50s/it]
# Steps: 56
# 58it [01:56,  1.50s/it]
# Steps: 57
# 59it [01:58,  1.49s/it]
# Steps: 58
# 60it [01:59,  1.49s/it]
# Steps: 59
# 61it [02:01,  1.50s/it]
# Steps: 60
# 62it [02:02,  1.50s/it]
# Steps: 61
# 63it [02:04,  1.49s/it]
# Steps: 62
# 64it [02:05,  1.49s/it]
# Steps: 63
# 65it [02:07,  1.50s/it]
# Steps: 64
# 66it [02:08,  1.49s/it]
# Steps: 65
# 67it [02:10,  1.48s/it]
# Steps: 66
# 68it [02:11,  1.49s/it]
# Steps: 67
# 69it [02:13,  1.52s/it]
# Steps: 68
# 70it [02:14,  1.53s/it]
# Steps: 69
# 71it [02:16,  1.52s/it]
# Steps: 70
# 72it [02:18,  1.53s/it]
# Steps: 71
# 73it [02:19,  1.53s/it]
# Steps: 72
# 74it [02:21,  1.53s/it]
# Steps: 73
# 75it [02:22,  1.53s/it]
# Steps: 74
# 76it [02:24,  1.52s/it]
# Steps: 75
# 77it [02:25,  1.51s/it]
# Steps: 76
# 78it [02:27,  1.50s/it]
# Steps: 77
# 79it [02:28,  1.49s/it]
# Steps: 78
# 80it [02:30,  1.50s/it]
# Steps: 79
# 81it [02:31,  1.50s/it]
# Steps: 80
# 82it [02:33,  1.49s/it]
# Steps: 81
# 83it [02:34,  1.49s/it]
# Steps: 82
# 84it [02:36,  1.50s/it]
# Steps: 83
# 85it [02:37,  1.50s/it]
# Steps: 84
# 86it [02:38,  1.49s/it]
# Steps: 85
# 87it [02:40,  1.49s/it]
# Steps: 86
# 88it [02:41,  1.48s/it]
# Steps: 87
# 89it [02:43,  1.48s/it]
# Steps: 88
# 90it [02:44,  1.48s/it]
# Steps: 89
# 91it [02:46,  1.48s/it]
# Steps: 90
# 92it [02:47,  1.48s/it]
# Steps: 91
# 93it [02:49,  1.49s/it]
# Steps: 92
# 94it [02:50,  1.47s/it]
# Steps: 93
# 95it [02:52,  1.47s/it]
# Steps: 94
# 96it [02:53,  1.48s/it]
# Steps: 95
# 97it [02:55,  1.49s/it]
# Steps: 96
# 98it [02:56,  1.49s/it]
# Steps: 97
# 99it [02:58,  1.49s/it]
# Steps: 98
# 100it [02:59,  1.48s/it]
# Steps: 99
# 101it [03:01,  1.48s/it]
# Steps: 100
# 102it [03:02,  1.48s/it]
# Steps: 101
# 103it [03:04,  1.49s/it]
# Steps: 102
# 104it [03:05,  1.48s/it]
# Steps: 103
# 105it [03:07,  1.48s/it]
# Steps: 104
# 106it [03:08,  1.47s/it]
# Steps: 105
# 107it [03:10,  1.48s/it]
# Steps: 106
# 108it [03:11,  1.49s/it]
# Steps: 107
# 109it [03:13,  1.49s/it]
# Steps: 108
# 110it [03:14,  1.49s/it]
# Steps: 109
# 111it [03:16,  1.49s/it]
# Steps: 110
# 112it [03:17,  1.48s/it]
# Steps: 111
# 113it [03:19,  1.49s/it]
# Steps: 112
# 114it [03:20,  1.49s/it]
# Steps: 113
# 115it [03:22,  1.49s/it]
# Steps: 114
# 116it [03:23,  1.48s/it]
# Steps: 115
# 117it [03:25,  1.49s/it]
# Steps: 116
# 118it [03:26,  1.49s/it]
# Steps: 117
# 119it [03:27,  1.49s/it]
# Steps: 118
# 120it [03:29,  1.50s/it]
# Steps: 119
# 121it [03:30,  1.49s/it]
# Steps: 120
# 122it [03:32,  1.48s/it]
# Steps: 121
# 123it [03:33,  1.49s/it]
# Steps: 122
# 124it [03:35,  1.48s/it]
# Steps: 123
# 125it [03:36,  1.48s/it]
# Steps: 124
# 126it [03:38,  1.49s/it]
# Steps: 125
# 127it [03:39,  1.48s/it]
# Steps: 126
# 128it [03:41,  1.48s/it]
# Steps: 127
# 129it [03:42,  1.49s/it]
# Steps: 128
# 130it [03:44,  1.48s/it]
# Steps: 129
# 131it [03:45,  1.49s/it]
# Steps: 130
# 132it [03:47,  1.48s/it]
# Steps: 131
# 133it [03:48,  1.48s/it]
# Steps: 132
# 134it [03:50,  1.48s/it]
# Steps: 133
# 135it [03:51,  1.49s/it]
# Steps: 134
# 136it [03:53,  1.49s/it]
# Steps: 135
# 137it [03:54,  1.49s/it]
# Steps: 136
# 138it [03:56,  1.48s/it]
# Steps: 137
# 139it [03:57,  1.48s/it]
# Steps: 138
# 140it [03:59,  1.48s/it]
# Steps: 139
# 141it [04:00,  1.48s/it]
# Steps: 140
# 142it [04:02,  1.48s/it]
# Steps: 141
# 143it [04:03,  1.49s/it]
# Steps: 142
# 144it [04:05,  1.48s/it]
# Steps: 143
# 145it [04:06,  1.49s/it]
# Steps: 144
# 146it [04:08,  1.49s/it]
# Steps: 145
# 147it [04:09,  1.49s/it]
# Steps: 146
# 148it [04:11,  1.49s/it]
# Steps: 147
# 149it [04:12,  1.49s/it]
# Steps: 148
# 150it [04:14,  1.49s/it]
# Steps: 149
# 151it [04:15,  1.49s/it]
# Steps: 150
# 152it [04:16,  1.48s/it]
# Steps: 151
# 153it [04:18,  1.48s/it]
# Steps: 152
# 154it [04:19,  1.48s/it]
# Steps: 153
# 155it [04:21,  1.49s/it]
# Steps: 154
# 156it [04:22,  1.48s/it]
# Steps: 155
# 157it [04:24,  1.48s/it]
# Steps: 156
# 158it [04:25,  1.49s/it]
# Steps: 157
# 159it [04:27,  1.49s/it]
# Steps: 158
# 160it [04:28,  1.48s/it]
# Steps: 159
# 161it [04:30,  1.48s/it]
# Steps: 160
# 162it [04:31,  1.48s/it]
# Steps: 161
# 162it [04:33,  1.69s/it]
# Steps: 162
# 1it [00:02,  2.80s/it]
# Steps: 0
# 2it [00:05,  2.60s/it]
# Steps: 1
# 3it [00:07,  2.44s/it]
# Steps: 2
# 4it [00:09,  2.42s/it]
# Steps: 3
# 5it [00:12,  2.40s/it]
# Steps: 4
# 6it [00:14,  2.35s/it]
# Steps: 5
# 6it [00:16,  2.68s/it]
# Steps: 6
# Time: 289.4708912372589

# %%
# np.save('train_features_ViTB32', train_features)
# np.save('train_labels_ViTB32', train_labels)
# np.save('val_features_ViTB32', val_features)
# np.save('val_labels_ViTB32', val_labels)

np.save('train_features_ViTB32_DA10', train_features)
np.save('train_labels_ViTB32_DA10', train_labels)
np.save('val_features_ViTB32_DA10', val_features)
np.save('val_labels_ViTB32_DA10', val_labels)

# %% [markdown]
# ## 分類器訓練

# %% [markdown]
# ### 普通建模

# %%
train_features = np.load('train_features_ViTB32_DA10.npy')
train_labels = np.load('train_labels_ViTB32_DA10.npy')
val_features = np.load('val_features_ViTB32_DA10.npy')
val_labels = np.load('val_labels_ViTB32_DA10.npy')
train_labels_OH = keras.utils.to_categorical(train_labels, num_classes=219)
val_labels_OH = keras.utils.to_categorical(val_labels, num_classes=219)

print(f'train_features.shape: {train_features.shape}')
print(f'train_labels.shape: {train_labels_OH.shape}')
print(f'val_features.shape: {val_features.shape}')
print(f'val_labels.shape: {val_labels_OH.shape}')
# Out:
# train_features.shape: (16300, 768)
# train_labels.shape: (16300, 219)
# val_features.shape: (657, 768)
# val_labels.shape: (657, 219)

# %%
inputs = Input(shape=(768,)) # CLIP output 的Embedding維度

x = Dense(1024)(inputs) #1
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Dropout(0.3)(x)

# 添加一个分类器
predictions = Dense(219, activation='softmax')(x)

# 构建我们需要训练的完整模型
model = Model(inputs=inputs, outputs=predictions)
print(model.summary())

# optimizer = Adam(lr=5e-5,decay=0.0001,beta_1=0.9,beta_2=0.999) #100e-6
optimizer = keras.optimizers.Nadam(lr=5e-5)
# optimizer = SGD(lr=1e-5, decay=1e-4, momentum=0.9, nesterov=True)
model.compile(loss = 'categorical_crossentropy',
              optimizer = optimizer,
              metrics = ['accuracy'])

epochs = 2000
aug_ratio = 1
batch_size = 32
steps_per_epoch = int(aug_ratio * train_features.shape[0] / batch_size)
save_dir = os.path.join(os.getcwd(), 'saved_models') # 儲存模型的路徑
model_name = 'Model_CLIP.h5' # 模型名稱

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(model_path, monitor = 'val_loss', save_best_only = True, verbose = 1)
earlystop = EarlyStopping(monitor = 'val_loss', patience = 10, verbose = 1, 
                          restore_best_weights=True) # patience=10為連續10次模型loss沒再下降就停止

model_history = model.fit(train_features, train_labels_OH, 
                          batch_size = batch_size,
                          epochs = epochs,
                          verbose = True,
                          callbacks = [checkpoint, earlystop],
                          validation_data = (val_features, val_labels_OH),
                          steps_per_epoch=steps_per_epoch
)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 768)]             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              787456
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_2 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 219)               224475
# =================================================================
# Total params: 1,016,027
# Trainable params: 1,013,979
# Non-trainable params: 2,048
# _________________________________________________________________
# None
# Epoch 1/2000
# 509/509 [==============================] - 7s 11ms/step - loss: 4.9893 - accuracy: 0.0686 - val_loss: 3.1187 - val_accuracy: 0.3988
#
# Epoch 00001: val_loss improved from inf to 3.11866, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 2/2000
# 509/509 [==============================] - 5s 11ms/step - loss: 2.5735 - accuracy: 0.5052 - val_loss: 2.1029 - val_accuracy: 0.5799
#
# Epoch 00002: val_loss improved from 3.11866 to 2.10290, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 3/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 1.5305 - accuracy: 0.7559 - val_loss: 1.6056 - val_accuracy: 0.6819
#
# Epoch 00003: val_loss improved from 2.10290 to 1.60560, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 4/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.9657 - accuracy: 0.8695 - val_loss: 1.3207 - val_accuracy: 0.7275
#
# Epoch 00004: val_loss improved from 1.60560 to 1.32067, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 5/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.6491 - accuracy: 0.9257 - val_loss: 1.1438 - val_accuracy: 0.7565
#
# Epoch 00005: val_loss improved from 1.32067 to 1.14376, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 6/2000
# 509/509 [==============================] - 5s 11ms/step - loss: 0.4542 - accuracy: 0.9558 - val_loss: 1.0192 - val_accuracy: 0.7732
#
# Epoch 00006: val_loss improved from 1.14376 to 1.01923, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 7/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.3303 - accuracy: 0.9744 - val_loss: 0.9254 - val_accuracy: 0.7778
#
# Epoch 00007: val_loss improved from 1.01923 to 0.92540, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 8/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.2475 - accuracy: 0.9837 - val_loss: 0.8583 - val_accuracy: 0.7839
#
# Epoch 00008: val_loss improved from 0.92540 to 0.85826, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 9/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.1861 - accuracy: 0.9891 - val_loss: 0.8132 - val_accuracy: 0.7915
#
# Epoch 00009: val_loss improved from 0.85826 to 0.81323, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 10/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.1438 - accuracy: 0.9925 - val_loss: 0.7729 - val_accuracy: 0.8037
#
# Epoch 00010: val_loss improved from 0.81323 to 0.77287, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 11/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.1114 - accuracy: 0.9943 - val_loss: 0.7410 - val_accuracy: 0.8158
#
# Epoch 00011: val_loss improved from 0.77287 to 0.74098, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 12/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0887 - accuracy: 0.9956 - val_loss: 0.7188 - val_accuracy: 0.8128
#
# Epoch 00012: val_loss improved from 0.74098 to 0.71881, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 13/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0715 - accuracy: 0.9979 - val_loss: 0.6896 - val_accuracy: 0.8250
#
# Epoch 00013: val_loss improved from 0.71881 to 0.68964, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 14/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0574 - accuracy: 0.9981 - val_loss: 0.6737 - val_accuracy: 0.8174
#
# Epoch 00014: val_loss improved from 0.68964 to 0.67368, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 15/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0471 - accuracy: 0.9988 - val_loss: 0.6655 - val_accuracy: 0.8174
#
# Epoch 00015: val_loss improved from 0.67368 to 0.66554, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 16/2000
# 509/509 [==============================] - 5s 11ms/step - loss: 0.0392 - accuracy: 0.9989 - val_loss: 0.6487 - val_accuracy: 0.8326
#
# Epoch 00016: val_loss improved from 0.66554 to 0.64872, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 17/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0312 - accuracy: 0.9995 - val_loss: 0.6354 - val_accuracy: 0.8280
#
# Epoch 00017: val_loss improved from 0.64872 to 0.63544, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 18/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0265 - accuracy: 0.9995 - val_loss: 0.6320 - val_accuracy: 0.8234
#
# Epoch 00018: val_loss improved from 0.63544 to 0.63200, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 19/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0236 - accuracy: 0.9996 - val_loss: 0.6140 - val_accuracy: 0.8371
#
# Epoch 00019: val_loss improved from 0.63200 to 0.61397, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 20/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0182 - accuracy: 0.9998 - val_loss: 0.6200 - val_accuracy: 0.8265
#
# Epoch 00020: val_loss did not improve from 0.61397
# Epoch 21/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0154 - accuracy: 0.9999 - val_loss: 0.6052 - val_accuracy: 0.8326
#
# Epoch 00021: val_loss improved from 0.61397 to 0.60524, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 22/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.6017 - val_accuracy: 0.8265
#
# Epoch 00022: val_loss improved from 0.60524 to 0.60166, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 23/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0110 - accuracy: 0.9999 - val_loss: 0.6058 - val_accuracy: 0.8326
#
# Epoch 00023: val_loss did not improve from 0.60166
# Epoch 24/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.5997 - val_accuracy: 0.8311
#
# Epoch 00024: val_loss improved from 0.60166 to 0.59965, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 25/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.5966 - val_accuracy: 0.8295
#
# Epoch 00025: val_loss improved from 0.59965 to 0.59661, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 26/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5995 - val_accuracy: 0.8295
#
# Epoch 00026: val_loss did not improve from 0.59661
# Epoch 27/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 0.5910 - val_accuracy: 0.8341
#
# Epoch 00027: val_loss improved from 0.59661 to 0.59098, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 28/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.5868 - val_accuracy: 0.8356
#
# Epoch 00028: val_loss improved from 0.59098 to 0.58685, saving model to D:\SideProject\Techniques\Tbrain_蘭花辨識\Orchid_Recognition\saved_models\Model_CLIP.h5
# Epoch 29/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.5982 - val_accuracy: 0.8356
#
# Epoch 00029: val_loss did not improve from 0.58685
# Epoch 30/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5902 - val_accuracy: 0.8341
#
# Epoch 00030: val_loss did not improve from 0.58685
# Epoch 31/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.5888 - val_accuracy: 0.8295
#
# Epoch 00031: val_loss did not improve from 0.58685
# Epoch 32/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.5889 - val_accuracy: 0.8387
#
# Epoch 00032: val_loss did not improve from 0.58685
# Epoch 33/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5941 - val_accuracy: 0.8295
#
# Epoch 00033: val_loss did not improve from 0.58685
# Epoch 34/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5943 - val_accuracy: 0.8326
#
# Epoch 00034: val_loss did not improve from 0.58685
# Epoch 35/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0026 - accuracy: 0.9999 - val_loss: 0.5982 - val_accuracy: 0.8356
#
# Epoch 00035: val_loss did not improve from 0.58685
# Epoch 36/2000
# 509/509 [==============================] - 5s 9ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5999 - val_accuracy: 0.8432
#
# Epoch 00036: val_loss did not improve from 0.58685
# Epoch 37/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6086 - val_accuracy: 0.8311
#
# Epoch 00037: val_loss did not improve from 0.58685
# Epoch 38/2000
# 509/509 [==============================] - 5s 10ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.8387
#
# Epoch 00038: val_loss did not improve from 0.58685
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping

# %%
final_model = keras.models.load_model('saved_models/Model_CLIP.h5')
scores = final_model.evaluate(val_features, val_labels_OH)
# Out:
# 21/21 [==============================] - 0s 7ms/step - loss: 0.5868 - accuracy: 0.8356

# %% [markdown]
# ### Keras_Tuner 建模實驗

# %%
train_features = np.load('train_features_ViTB32_DA2.npy')
train_labels = np.load('train_labels_ViTB32_DA2.npy')
val_features = np.load('val_features_ViTB32_DA2.npy')
val_labels = np.load('val_labels_ViTB32_DA2.npy')

print(f'train_featrues.shape:{train_features.shape}')
print(f'train_labels.shape:{train_labels.shape}')
print(f'val_features.shape:{val_features.shape}')
print(f'val_labels.shape:{val_labels.shape}')
# Out:
# train_featrues.shape:(16300, 768)
# train_labels.shape:(16300,)
# val_features.shape:(657, 768)
# val_labels.shape:(657,)

# %%
# 對 label進行 OneHotEncoding-219類別
train_labels_OH = keras.utils.to_categorical(train_labels, 219)  
print(train_labels_OH.shape)
val_labels_OH = keras.utils.to_categorical(val_labels, 219)  
print(val_labels_OH.shape)
# Out:
# (16300, 219)
# (657, 219)

# %%
def model_builder(hp):
    inputs = Input(shape=(768,)) # CLIP output 的Embedding維度

    x = Dense(hp.Choice('units', [256, 512, 1024]), activation='relu')(inputs) #1
    x = Activation('relu')(x)
    x = Dropout(rate=hp.Float("rate", min_value=0.0, max_value=0.7, step=0.1))(x)

    # 添加一个分类器
    predictions = Dense(219, activation='softmax')(x)

    # 构建我们需要训练的完整模型
    model = Model(inputs=inputs, outputs=predictions)
    print(model.summary())

    learning_rate = hp.Float("lr", min_value=1e-5, max_value=1e-4, sampling="log")
    optimizer = Adam(lr=learning_rate,decay=0.0001,beta_1=0.9,beta_2=0.999) #100e-6
    # optimizer = SGD(lr=1e-5, decay=1e-4, momentum=0.9, nesterov=True)
    model.compile(loss = 'categorical_crossentropy',
                 optimizer = optimizer,
                 metrics = ['accuracy'])

    return model

# %%
epochs = 2000
aug_ratio = 1
batch_size = 32
steps_per_epoch = int(aug_ratio * train_features.shape[0] / batch_size)
save_dir = os.path.join(os.getcwd(), 'saved_models') # 儲存模型的路徑
model_name = 'Model_CLIP.h5' # 模型名稱

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(model_path, monitor = 'val_loss', save_best_only = True, verbose = 1)
earlystop = EarlyStopping(monitor = 'val_loss', patience = 10, verbose = 1) # patience=10為連續10次模型loss沒再下降就停止

# %%
tuner = kt.RandomSearch(model_builder, objective='val_loss', max_trials=20)

tuner.search(train_features, train_labels_OH, 
             batch_size = batch_size,
             epochs = epochs,
             verbose = True,
             callbacks = [checkpoint, earlystop],
             validation_data = (val_features, val_labels_OH),
             steps_per_epoch=steps_per_epoch
)
# Out:
# Trial 7 Complete [00h 07m 30s]
# val_loss: 0.6191866993904114
#
# Best val_loss So Far: 0.5760288834571838
# Total elapsed time: 01h 37m 32s
#
# Search: Running Trial #8
#
# Value             |Best Value So Far |Hyperparameter
# 512               |1024              |units
# 0.4               |0.6               |rate
# 1.4538e-05        |2.5634e-05        |lr
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 768)]             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               393728
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 219)               112347
# =================================================================
# Total params: 506,075
# Trainable params: 506,075
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2000
# 509/509 [==============================] - 2s 3ms/step - loss: 5.5856 - accuracy: 0.0054 - val_loss: 5.2482 - val_accuracy: 0.0137
#
# Epoch 00001: val_loss improved from inf to 5.24815, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 2/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 5.2382 - accuracy: 0.0160 - val_loss: 4.9901 - val_accuracy: 0.0487
#
# Epoch 00002: val_loss improved from 5.24815 to 4.99008, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 3/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 4.9537 - accuracy: 0.0391 - val_loss: 4.7227 - val_accuracy: 0.0944
#
# Epoch 00003: val_loss improved from 4.99008 to 4.72269, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 4/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 4.6867 - accuracy: 0.0685 - val_loss: 4.4685 - val_accuracy: 0.1400
#
# Epoch 00004: val_loss improved from 4.72269 to 4.46853, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 5/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 4.4372 - accuracy: 0.0991 - val_loss: 4.2464 - val_accuracy: 0.1933
#
# Epoch 00005: val_loss improved from 4.46853 to 4.24636, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 6/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 4.2057 - accuracy: 0.1338 - val_loss: 4.0538 - val_accuracy: 0.2420
#
# Epoch 00006: val_loss improved from 4.24636 to 4.05376, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 7/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 4.0285 - accuracy: 0.1608 - val_loss: 3.8870 - val_accuracy: 0.2831
#
# Epoch 00007: val_loss improved from 4.05376 to 3.88701, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 8/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.8502 - accuracy: 0.1918 - val_loss: 3.7384 - val_accuracy: 0.3318
#
# Epoch 00008: val_loss improved from 3.88701 to 3.73835, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 9/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.6970 - accuracy: 0.2289 - val_loss: 3.6042 - val_accuracy: 0.3607
#
# Epoch 00009: val_loss improved from 3.73835 to 3.60422, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 10/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.5652 - accuracy: 0.2475 - val_loss: 3.4807 - val_accuracy: 0.3896
#
# Epoch 00010: val_loss improved from 3.60422 to 3.48068, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 11/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.4236 - accuracy: 0.2833 - val_loss: 3.3688 - val_accuracy: 0.4155
#
# Epoch 00011: val_loss improved from 3.48068 to 3.36876, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 12/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.3258 - accuracy: 0.2868 - val_loss: 3.2678 - val_accuracy: 0.4307
#
# Epoch 00012: val_loss improved from 3.36876 to 3.26777, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 13/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 3.2121 - accuracy: 0.3136 - val_loss: 3.1742 - val_accuracy: 0.4414
#
# Epoch 00013: val_loss improved from 3.26777 to 3.17423, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 14/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 3.1173 - accuracy: 0.3316 - val_loss: 3.0884 - val_accuracy: 0.4642
#
# Epoch 00014: val_loss improved from 3.17423 to 3.08837, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 15/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.0176 - accuracy: 0.3508 - val_loss: 3.0082 - val_accuracy: 0.4749
#
# Epoch 00015: val_loss improved from 3.08837 to 3.00824, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 16/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.9436 - accuracy: 0.3671 - val_loss: 2.9344 - val_accuracy: 0.4977
#
# Epoch 00016: val_loss improved from 3.00824 to 2.93440, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 17/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.8578 - accuracy: 0.3835 - val_loss: 2.8656 - val_accuracy: 0.5114
#
# Epoch 00017: val_loss improved from 2.93440 to 2.86564, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 18/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.7901 - accuracy: 0.3914 - val_loss: 2.8020 - val_accuracy: 0.5221
#
# Epoch 00018: val_loss improved from 2.86564 to 2.80203, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 19/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.7085 - accuracy: 0.4055 - val_loss: 2.7414 - val_accuracy: 0.5403
#
# Epoch 00019: val_loss improved from 2.80203 to 2.74145, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 20/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.6634 - accuracy: 0.4222 - val_loss: 2.6854 - val_accuracy: 0.5525
#
# Epoch 00020: val_loss improved from 2.74145 to 2.68539, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 21/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.5870 - accuracy: 0.4341 - val_loss: 2.6330 - val_accuracy: 0.5616
#
# Epoch 00021: val_loss improved from 2.68539 to 2.63300, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 22/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.5223 - accuracy: 0.4496 - val_loss: 2.5837 - val_accuracy: 0.5662
#
# Epoch 00022: val_loss improved from 2.63300 to 2.58369, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 23/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.4894 - accuracy: 0.4521 - val_loss: 2.5369 - val_accuracy: 0.5769
#
# Epoch 00023: val_loss improved from 2.58369 to 2.53686, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 24/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.4270 - accuracy: 0.4689 - val_loss: 2.4921 - val_accuracy: 0.5936
#
# Epoch 00024: val_loss improved from 2.53686 to 2.49208, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 25/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.3890 - accuracy: 0.4749 - val_loss: 2.4498 - val_accuracy: 0.5936
#
# Epoch 00025: val_loss improved from 2.49208 to 2.44985, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 26/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.3201 - accuracy: 0.4950 - val_loss: 2.4102 - val_accuracy: 0.5921
#
# Epoch 00026: val_loss improved from 2.44985 to 2.41020, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 27/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.2730 - accuracy: 0.4989 - val_loss: 2.3707 - val_accuracy: 0.6058
#
# Epoch 00027: val_loss improved from 2.41020 to 2.37072, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 28/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.2677 - accuracy: 0.5033 - val_loss: 2.3346 - val_accuracy: 0.6119
#
# Epoch 00028: val_loss improved from 2.37072 to 2.33456, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 29/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.1872 - accuracy: 0.5158 - val_loss: 2.2993 - val_accuracy: 0.6119
#
# Epoch 00029: val_loss improved from 2.33456 to 2.29932, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 30/2000
# 509/509 [==============================] - 2s 3ms/step - loss: 2.1551 - accuracy: 0.5309 - val_loss: 2.2656 - val_accuracy: 0.6134
#
# Epoch 00030: val_loss improved from 2.29932 to 2.26558, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 31/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.1226 - accuracy: 0.5391 - val_loss: 2.2339 - val_accuracy: 0.6195
#
# Epoch 00031: val_loss improved from 2.26558 to 2.23386, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 32/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.0844 - accuracy: 0.5483 - val_loss: 2.2033 - val_accuracy: 0.6256
#
# Epoch 00032: val_loss improved from 2.23386 to 2.20326, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 33/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.0470 - accuracy: 0.5484 - val_loss: 2.1735 - val_accuracy: 0.6240
#
# Epoch 00033: val_loss improved from 2.20326 to 2.17349, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 34/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.0199 - accuracy: 0.5555 - val_loss: 2.1462 - val_accuracy: 0.6286
#
# Epoch 00034: val_loss improved from 2.17349 to 2.14615, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 35/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.9945 - accuracy: 0.5646 - val_loss: 2.1194 - val_accuracy: 0.6286
#
# Epoch 00035: val_loss improved from 2.14615 to 2.11937, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 36/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.9464 - accuracy: 0.5754 - val_loss: 2.0932 - val_accuracy: 0.6393
#
# Epoch 00036: val_loss improved from 2.11937 to 2.09320, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 37/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.9321 - accuracy: 0.5779 - val_loss: 2.0689 - val_accuracy: 0.6377
#
# Epoch 00037: val_loss improved from 2.09320 to 2.06887, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 38/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.8988 - accuracy: 0.5794 - val_loss: 2.0450 - val_accuracy: 0.6454
#
# Epoch 00038: val_loss improved from 2.06887 to 2.04503, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 39/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.8841 - accuracy: 0.5874 - val_loss: 2.0225 - val_accuracy: 0.6454
#
# Epoch 00039: val_loss improved from 2.04503 to 2.02247, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 40/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.8449 - accuracy: 0.5942 - val_loss: 2.0011 - val_accuracy: 0.6530
#
# Epoch 00040: val_loss improved from 2.02247 to 2.00113, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 41/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.8368 - accuracy: 0.5999 - val_loss: 1.9787 - val_accuracy: 0.6560
#
# Epoch 00041: val_loss improved from 2.00113 to 1.97869, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 42/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.7903 - accuracy: 0.6093 - val_loss: 1.9576 - val_accuracy: 0.6606
#
# Epoch 00042: val_loss improved from 1.97869 to 1.95764, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 43/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.7886 - accuracy: 0.6086 - val_loss: 1.9377 - val_accuracy: 0.6697
#
# Epoch 00043: val_loss improved from 1.95764 to 1.93771, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 44/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.7666 - accuracy: 0.6110 - val_loss: 1.9189 - val_accuracy: 0.6636
#
# Epoch 00044: val_loss improved from 1.93771 to 1.91891, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 45/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.7344 - accuracy: 0.6185 - val_loss: 1.8997 - val_accuracy: 0.6667
#
# Epoch 00045: val_loss improved from 1.91891 to 1.89974, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 46/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.7113 - accuracy: 0.6264 - val_loss: 1.8818 - val_accuracy: 0.6743
#
# Epoch 00046: val_loss improved from 1.89974 to 1.88176, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 47/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.6978 - accuracy: 0.6201 - val_loss: 1.8645 - val_accuracy: 0.6728
#
# Epoch 00047: val_loss improved from 1.88176 to 1.86447, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 48/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.6380 - accuracy: 0.6446 - val_loss: 1.8474 - val_accuracy: 0.6697
#
# Epoch 00048: val_loss improved from 1.86447 to 1.84742, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 49/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.6596 - accuracy: 0.6397 - val_loss: 1.8313 - val_accuracy: 0.6880
#
# Epoch 00049: val_loss improved from 1.84742 to 1.83131, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 50/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.6247 - accuracy: 0.6473 - val_loss: 1.8153 - val_accuracy: 0.6849
#
# Epoch 00050: val_loss improved from 1.83131 to 1.81532, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 51/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.6082 - accuracy: 0.6518 - val_loss: 1.8011 - val_accuracy: 0.6788
#
# Epoch 00051: val_loss improved from 1.81532 to 1.80109, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 52/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.6014 - accuracy: 0.6500 - val_loss: 1.7867 - val_accuracy: 0.6773
#
# Epoch 00052: val_loss improved from 1.80109 to 1.78672, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 53/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.5937 - accuracy: 0.6454 - val_loss: 1.7723 - val_accuracy: 0.6819
#
# Epoch 00053: val_loss improved from 1.78672 to 1.77231, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 54/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.5650 - accuracy: 0.6531 - val_loss: 1.7576 - val_accuracy: 0.6849
#
# Epoch 00054: val_loss improved from 1.77231 to 1.75756, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 55/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.5383 - accuracy: 0.6590 - val_loss: 1.7440 - val_accuracy: 0.6910
#
# Epoch 00055: val_loss improved from 1.75756 to 1.74405, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 56/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.5381 - accuracy: 0.6711 - val_loss: 1.7308 - val_accuracy: 0.6941
#
# Epoch 00056: val_loss improved from 1.74405 to 1.73077, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 57/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.5086 - accuracy: 0.6702 - val_loss: 1.7189 - val_accuracy: 0.6925
#
# Epoch 00057: val_loss improved from 1.73077 to 1.71889, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 58/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.5100 - accuracy: 0.6673 - val_loss: 1.7058 - val_accuracy: 0.6956
#
# Epoch 00058: val_loss improved from 1.71889 to 1.70585, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 59/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4926 - accuracy: 0.6722 - val_loss: 1.6939 - val_accuracy: 0.7017
#
# Epoch 00059: val_loss improved from 1.70585 to 1.69393, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 60/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.4624 - accuracy: 0.6829 - val_loss: 1.6810 - val_accuracy: 0.6956
#
# Epoch 00060: val_loss improved from 1.69393 to 1.68104, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 61/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4427 - accuracy: 0.6910 - val_loss: 1.6692 - val_accuracy: 0.7017
#
# Epoch 00061: val_loss improved from 1.68104 to 1.66920, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 62/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4619 - accuracy: 0.6730 - val_loss: 1.6575 - val_accuracy: 0.7002
#
# Epoch 00062: val_loss improved from 1.66920 to 1.65753, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 63/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4313 - accuracy: 0.6838 - val_loss: 1.6464 - val_accuracy: 0.7017
#
# Epoch 00063: val_loss improved from 1.65753 to 1.64645, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 64/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4191 - accuracy: 0.6860 - val_loss: 1.6360 - val_accuracy: 0.7002
#
# Epoch 00064: val_loss improved from 1.64645 to 1.63604, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 65/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4232 - accuracy: 0.6837 - val_loss: 1.6258 - val_accuracy: 0.7062
#
# Epoch 00065: val_loss improved from 1.63604 to 1.62576, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 66/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4046 - accuracy: 0.6905 - val_loss: 1.6150 - val_accuracy: 0.7047
#
# Epoch 00066: val_loss improved from 1.62576 to 1.61504, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 67/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.3592 - accuracy: 0.7051 - val_loss: 1.6051 - val_accuracy: 0.7093
#
# Epoch 00067: val_loss improved from 1.61504 to 1.60508, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 68/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.3742 - accuracy: 0.7027 - val_loss: 1.5957 - val_accuracy: 0.7062
#
# Epoch 00068: val_loss improved from 1.60508 to 1.59573, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 69/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.3670 - accuracy: 0.6990 - val_loss: 1.5866 - val_accuracy: 0.7047
#
# Epoch 00069: val_loss improved from 1.59573 to 1.58661, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 70/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.3370 - accuracy: 0.7071 - val_loss: 1.5766 - val_accuracy: 0.7017
#
# Epoch 00070: val_loss improved from 1.58661 to 1.57656, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 71/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.3417 - accuracy: 0.7052 - val_loss: 1.5677 - val_accuracy: 0.7093
#
# Epoch 00071: val_loss improved from 1.57656 to 1.56767, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 72/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.3274 - accuracy: 0.7113 - val_loss: 1.5587 - val_accuracy: 0.7078
#
# Epoch 00072: val_loss improved from 1.56767 to 1.55866, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 73/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2988 - accuracy: 0.7233 - val_loss: 1.5499 - val_accuracy: 0.7108
#
# Epoch 00073: val_loss improved from 1.55866 to 1.54985, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 74/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.3078 - accuracy: 0.7124 - val_loss: 1.5413 - val_accuracy: 0.7062
#
# Epoch 00074: val_loss improved from 1.54985 to 1.54128, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 75/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.3056 - accuracy: 0.7157 - val_loss: 1.5336 - val_accuracy: 0.7093
#
# Epoch 00075: val_loss improved from 1.54128 to 1.53365, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 76/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2737 - accuracy: 0.7244 - val_loss: 1.5253 - val_accuracy: 0.7108
#
# Epoch 00076: val_loss improved from 1.53365 to 1.52526, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 77/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2718 - accuracy: 0.7279 - val_loss: 1.5168 - val_accuracy: 0.7123
#
# Epoch 00077: val_loss improved from 1.52526 to 1.51678, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 78/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2811 - accuracy: 0.7159 - val_loss: 1.5089 - val_accuracy: 0.7108
#
# Epoch 00078: val_loss improved from 1.51678 to 1.50892, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 79/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2695 - accuracy: 0.7248 - val_loss: 1.5016 - val_accuracy: 0.7078
#
# Epoch 00079: val_loss improved from 1.50892 to 1.50161, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 80/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2494 - accuracy: 0.7259 - val_loss: 1.4943 - val_accuracy: 0.7093
#
# Epoch 00080: val_loss improved from 1.50161 to 1.49425, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 81/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.2365 - accuracy: 0.7359 - val_loss: 1.4868 - val_accuracy: 0.7123
#
# Epoch 00081: val_loss improved from 1.49425 to 1.48680, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 82/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.2482 - accuracy: 0.7269 - val_loss: 1.4792 - val_accuracy: 0.7108
#
# Epoch 00082: val_loss improved from 1.48680 to 1.47924, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 83/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2183 - accuracy: 0.7377 - val_loss: 1.4729 - val_accuracy: 0.7108
#
# Epoch 00083: val_loss improved from 1.47924 to 1.47287, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 84/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.2172 - accuracy: 0.7350 - val_loss: 1.4660 - val_accuracy: 0.7123
#
# Epoch 00084: val_loss improved from 1.47287 to 1.46596, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 85/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1955 - accuracy: 0.7479 - val_loss: 1.4587 - val_accuracy: 0.7139
#
# Epoch 00085: val_loss improved from 1.46596 to 1.45865, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 86/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1973 - accuracy: 0.7374 - val_loss: 1.4511 - val_accuracy: 0.7215
#
# Epoch 00086: val_loss improved from 1.45865 to 1.45109, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 87/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1872 - accuracy: 0.7474 - val_loss: 1.4449 - val_accuracy: 0.7184
#
# Epoch 00087: val_loss improved from 1.45109 to 1.44488, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 88/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1941 - accuracy: 0.7410 - val_loss: 1.4389 - val_accuracy: 0.7169
#
# Epoch 00088: val_loss improved from 1.44488 to 1.43887, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 89/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1683 - accuracy: 0.7511 - val_loss: 1.4318 - val_accuracy: 0.7215
#
# Epoch 00089: val_loss improved from 1.43887 to 1.43178, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 90/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1856 - accuracy: 0.7439 - val_loss: 1.4255 - val_accuracy: 0.7184
#
# Epoch 00090: val_loss improved from 1.43178 to 1.42554, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 91/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1616 - accuracy: 0.7495 - val_loss: 1.4196 - val_accuracy: 0.7169
#
# Epoch 00091: val_loss improved from 1.42554 to 1.41959, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 92/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1446 - accuracy: 0.7509 - val_loss: 1.4136 - val_accuracy: 0.7199
#
# Epoch 00092: val_loss improved from 1.41959 to 1.41358, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 93/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1546 - accuracy: 0.7477 - val_loss: 1.4079 - val_accuracy: 0.7139
#
# Epoch 00093: val_loss improved from 1.41358 to 1.40791, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 94/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1316 - accuracy: 0.7598 - val_loss: 1.4018 - val_accuracy: 0.7169
#
# Epoch 00094: val_loss improved from 1.40791 to 1.40178, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 95/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1316 - accuracy: 0.7568 - val_loss: 1.3964 - val_accuracy: 0.7169
#
# Epoch 00095: val_loss improved from 1.40178 to 1.39635, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 96/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1354 - accuracy: 0.7567 - val_loss: 1.3904 - val_accuracy: 0.7184
#
# Epoch 00096: val_loss improved from 1.39635 to 1.39039, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 97/2000
# 509/509 [==============================] - 2s 3ms/step - loss: 1.1308 - accuracy: 0.7537 - val_loss: 1.3847 - val_accuracy: 0.7230
#
# Epoch 00097: val_loss improved from 1.39039 to 1.38467, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 98/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1164 - accuracy: 0.7617 - val_loss: 1.3798 - val_accuracy: 0.7215
#
# Epoch 00098: val_loss improved from 1.38467 to 1.37976, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 99/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1042 - accuracy: 0.7636 - val_loss: 1.3744 - val_accuracy: 0.7245
#
# Epoch 00099: val_loss improved from 1.37976 to 1.37436, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 100/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0950 - accuracy: 0.7591 - val_loss: 1.3694 - val_accuracy: 0.7230
#
# Epoch 00100: val_loss improved from 1.37436 to 1.36940, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 101/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0927 - accuracy: 0.7667 - val_loss: 1.3648 - val_accuracy: 0.7199
#
# Epoch 00101: val_loss improved from 1.36940 to 1.36481, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 102/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0988 - accuracy: 0.7601 - val_loss: 1.3596 - val_accuracy: 0.7199
#
# Epoch 00102: val_loss improved from 1.36481 to 1.35958, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 103/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.1068 - accuracy: 0.7580 - val_loss: 1.3546 - val_accuracy: 0.7199
#
# Epoch 00103: val_loss improved from 1.35958 to 1.35463, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 104/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.0581 - accuracy: 0.7709 - val_loss: 1.3497 - val_accuracy: 0.7215
#
# Epoch 00104: val_loss improved from 1.35463 to 1.34973, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 105/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0734 - accuracy: 0.7717 - val_loss: 1.3447 - val_accuracy: 0.7215
#
# Epoch 00105: val_loss improved from 1.34973 to 1.34474, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 106/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0813 - accuracy: 0.7608 - val_loss: 1.3399 - val_accuracy: 0.7230
#
# Epoch 00106: val_loss improved from 1.34474 to 1.33986, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 107/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0831 - accuracy: 0.7625 - val_loss: 1.3355 - val_accuracy: 0.7260
#
# Epoch 00107: val_loss improved from 1.33986 to 1.33548, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 108/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0523 - accuracy: 0.7753 - val_loss: 1.3307 - val_accuracy: 0.7215
#
# Epoch 00108: val_loss improved from 1.33548 to 1.33074, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 109/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0513 - accuracy: 0.7789 - val_loss: 1.3261 - val_accuracy: 0.7230
#
# Epoch 00109: val_loss improved from 1.33074 to 1.32607, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 110/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0482 - accuracy: 0.7755 - val_loss: 1.3217 - val_accuracy: 0.7245
#
# Epoch 00110: val_loss improved from 1.32607 to 1.32170, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 111/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0312 - accuracy: 0.7837 - val_loss: 1.3169 - val_accuracy: 0.7230
#
# Epoch 00111: val_loss improved from 1.32170 to 1.31689, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 112/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0335 - accuracy: 0.7731 - val_loss: 1.3122 - val_accuracy: 0.7260
#
# Epoch 00112: val_loss improved from 1.31689 to 1.31216, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 113/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0328 - accuracy: 0.7776 - val_loss: 1.3080 - val_accuracy: 0.7275
#
# Epoch 00113: val_loss improved from 1.31216 to 1.30801, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 114/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0260 - accuracy: 0.7807 - val_loss: 1.3040 - val_accuracy: 0.7245
#
# Epoch 00114: val_loss improved from 1.30801 to 1.30399, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 115/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.0158 - accuracy: 0.7817 - val_loss: 1.2994 - val_accuracy: 0.7291
#
# Epoch 00115: val_loss improved from 1.30399 to 1.29939, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 116/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.0135 - accuracy: 0.7812 - val_loss: 1.2957 - val_accuracy: 0.7291
#
# Epoch 00116: val_loss improved from 1.29939 to 1.29571, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 117/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.0090 - accuracy: 0.7840 - val_loss: 1.2919 - val_accuracy: 0.7291
#
# Epoch 00117: val_loss improved from 1.29571 to 1.29186, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 118/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0030 - accuracy: 0.7863 - val_loss: 1.2875 - val_accuracy: 0.7291
#
# Epoch 00118: val_loss improved from 1.29186 to 1.28753, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 119/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9904 - accuracy: 0.7876 - val_loss: 1.2839 - val_accuracy: 0.7291
#
# Epoch 00119: val_loss improved from 1.28753 to 1.28391, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 120/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.0163 - accuracy: 0.7815 - val_loss: 1.2794 - val_accuracy: 0.7321
#
# Epoch 00120: val_loss improved from 1.28391 to 1.27939, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 121/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9802 - accuracy: 0.7922 - val_loss: 1.2753 - val_accuracy: 0.7291
#
# Epoch 00121: val_loss improved from 1.27939 to 1.27532, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 122/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9860 - accuracy: 0.7910 - val_loss: 1.2722 - val_accuracy: 0.7352
#
# Epoch 00122: val_loss improved from 1.27532 to 1.27223, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 123/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9825 - accuracy: 0.7821 - val_loss: 1.2687 - val_accuracy: 0.7306
#
# Epoch 00123: val_loss improved from 1.27223 to 1.26872, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 124/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9724 - accuracy: 0.7914 - val_loss: 1.2653 - val_accuracy: 0.7336
#
# Epoch 00124: val_loss improved from 1.26872 to 1.26527, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 125/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9822 - accuracy: 0.7865 - val_loss: 1.2613 - val_accuracy: 0.7321
#
# Epoch 00125: val_loss improved from 1.26527 to 1.26127, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 126/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9638 - accuracy: 0.7955 - val_loss: 1.2575 - val_accuracy: 0.7336
#
# Epoch 00126: val_loss improved from 1.26127 to 1.25748, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 127/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9566 - accuracy: 0.7919 - val_loss: 1.2544 - val_accuracy: 0.7321
#
# Epoch 00127: val_loss improved from 1.25748 to 1.25437, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 128/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9718 - accuracy: 0.7891 - val_loss: 1.2507 - val_accuracy: 0.7352
#
# Epoch 00128: val_loss improved from 1.25437 to 1.25066, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 129/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9514 - accuracy: 0.8031 - val_loss: 1.2475 - val_accuracy: 0.7306
#
# Epoch 00129: val_loss improved from 1.25066 to 1.24749, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 130/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9643 - accuracy: 0.7905 - val_loss: 1.2442 - val_accuracy: 0.7352
#
# Epoch 00130: val_loss improved from 1.24749 to 1.24423, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 131/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9448 - accuracy: 0.8006 - val_loss: 1.2402 - val_accuracy: 0.7321
#
# Epoch 00131: val_loss improved from 1.24423 to 1.24021, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 132/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9356 - accuracy: 0.7998 - val_loss: 1.2373 - val_accuracy: 0.7382
#
# Epoch 00132: val_loss improved from 1.24021 to 1.23731, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 133/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9360 - accuracy: 0.8043 - val_loss: 1.2336 - val_accuracy: 0.7352
#
# Epoch 00133: val_loss improved from 1.23731 to 1.23362, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 134/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9422 - accuracy: 0.7967 - val_loss: 1.2307 - val_accuracy: 0.7367
#
# Epoch 00134: val_loss improved from 1.23362 to 1.23075, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 135/2000
# 509/509 [==============================] - 2s 3ms/step - loss: 0.9312 - accuracy: 0.7988 - val_loss: 1.2273 - val_accuracy: 0.7336
#
# Epoch 00135: val_loss improved from 1.23075 to 1.22732, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 136/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.9198 - accuracy: 0.8064 - val_loss: 1.2241 - val_accuracy: 0.7367
#
# Epoch 00136: val_loss improved from 1.22732 to 1.22406, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 137/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9155 - accuracy: 0.8023 - val_loss: 1.2213 - val_accuracy: 0.7352
#
# Epoch 00137: val_loss improved from 1.22406 to 1.22132, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 138/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9129 - accuracy: 0.8081 - val_loss: 1.2180 - val_accuracy: 0.7352
#
# Epoch 00138: val_loss improved from 1.22132 to 1.21801, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 139/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9088 - accuracy: 0.8067 - val_loss: 1.2150 - val_accuracy: 0.7336
#
# Epoch 00139: val_loss improved from 1.21801 to 1.21499, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 140/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8956 - accuracy: 0.8082 - val_loss: 1.2114 - val_accuracy: 0.7336
#
# Epoch 00140: val_loss improved from 1.21499 to 1.21144, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 141/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9122 - accuracy: 0.8042 - val_loss: 1.2089 - val_accuracy: 0.7352
#
# Epoch 00141: val_loss improved from 1.21144 to 1.20891, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 142/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9104 - accuracy: 0.8045 - val_loss: 1.2059 - val_accuracy: 0.7428
#
# Epoch 00142: val_loss improved from 1.20891 to 1.20592, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 143/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8892 - accuracy: 0.8122 - val_loss: 1.2031 - val_accuracy: 0.7352
#
# Epoch 00143: val_loss improved from 1.20592 to 1.20309, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 144/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8994 - accuracy: 0.8129 - val_loss: 1.2005 - val_accuracy: 0.7352
#
# Epoch 00144: val_loss improved from 1.20309 to 1.20046, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 145/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8899 - accuracy: 0.8122 - val_loss: 1.1977 - val_accuracy: 0.7336
#
# Epoch 00145: val_loss improved from 1.20046 to 1.19772, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 146/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8813 - accuracy: 0.8082 - val_loss: 1.1947 - val_accuracy: 0.7412
#
# Epoch 00146: val_loss improved from 1.19772 to 1.19470, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 147/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8921 - accuracy: 0.8125 - val_loss: 1.1920 - val_accuracy: 0.7428
#
# Epoch 00147: val_loss improved from 1.19470 to 1.19195, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 148/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8983 - accuracy: 0.8041 - val_loss: 1.1895 - val_accuracy: 0.7397
#
# Epoch 00148: val_loss improved from 1.19195 to 1.18948, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 149/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8791 - accuracy: 0.8119 - val_loss: 1.1869 - val_accuracy: 0.7397
#
# Epoch 00149: val_loss improved from 1.18948 to 1.18694, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 150/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8779 - accuracy: 0.8061 - val_loss: 1.1839 - val_accuracy: 0.7412
#
# Epoch 00150: val_loss improved from 1.18694 to 1.18385, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 151/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8726 - accuracy: 0.8152 - val_loss: 1.1814 - val_accuracy: 0.7382
#
# Epoch 00151: val_loss improved from 1.18385 to 1.18144, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 152/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8692 - accuracy: 0.8141 - val_loss: 1.1789 - val_accuracy: 0.7397
#
# Epoch 00152: val_loss improved from 1.18144 to 1.17886, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 153/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8689 - accuracy: 0.8166 - val_loss: 1.1764 - val_accuracy: 0.7382
#
# Epoch 00153: val_loss improved from 1.17886 to 1.17638, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 154/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8637 - accuracy: 0.8152 - val_loss: 1.1737 - val_accuracy: 0.7443
#
# Epoch 00154: val_loss improved from 1.17638 to 1.17368, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 155/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8474 - accuracy: 0.8236 - val_loss: 1.1710 - val_accuracy: 0.7412
#
# Epoch 00155: val_loss improved from 1.17368 to 1.17105, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 156/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8568 - accuracy: 0.8154 - val_loss: 1.1686 - val_accuracy: 0.7412
#
# Epoch 00156: val_loss improved from 1.17105 to 1.16865, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 157/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8527 - accuracy: 0.8211 - val_loss: 1.1666 - val_accuracy: 0.7412
#
# Epoch 00157: val_loss improved from 1.16865 to 1.16656, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 158/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8487 - accuracy: 0.8182 - val_loss: 1.1638 - val_accuracy: 0.7458
#
# Epoch 00158: val_loss improved from 1.16656 to 1.16383, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 159/2000
# ...
#
# Epoch 01160: val_loss improved from 0.73637 to 0.73622, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1161/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3081 - accuracy: 0.9418 - val_loss: 0.7361 - val_accuracy: 0.8158
#
# Epoch 01161: val_loss improved from 0.73622 to 0.73610, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1162/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3104 - accuracy: 0.9439 - val_loss: 0.7361 - val_accuracy: 0.8158
#
# Epoch 01162: val_loss improved from 0.73610 to 0.73606, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1163/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3110 - accuracy: 0.9416 - val_loss: 0.7361 - val_accuracy: 0.8158
#
# Epoch 01163: val_loss did not improve from 0.73606
# Epoch 1164/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3152 - accuracy: 0.9414 - val_loss: 0.7360 - val_accuracy: 0.8158
#
# Epoch 01164: val_loss improved from 0.73606 to 0.73598, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1165/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3126 - accuracy: 0.9407 - val_loss: 0.7358 - val_accuracy: 0.8158
#
# Epoch 01165: val_loss improved from 0.73598 to 0.73582, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1166/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3136 - accuracy: 0.9403 - val_loss: 0.7358 - val_accuracy: 0.8158
#
# Epoch 01166: val_loss improved from 0.73582 to 0.73580, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1167/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3183 - accuracy: 0.9387 - val_loss: 0.7357 - val_accuracy: 0.8158
#
# Epoch 01167: val_loss improved from 0.73580 to 0.73568, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1168/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3106 - accuracy: 0.9441 - val_loss: 0.7356 - val_accuracy: 0.8158
#
# Epoch 01168: val_loss improved from 0.73568 to 0.73556, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1169/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3144 - accuracy: 0.9429 - val_loss: 0.7354 - val_accuracy: 0.8158
#
# Epoch 01169: val_loss improved from 0.73556 to 0.73541, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1170/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3193 - accuracy: 0.9393 - val_loss: 0.7354 - val_accuracy: 0.8158
#
# Epoch 01170: val_loss improved from 0.73541 to 0.73538, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1171/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3132 - accuracy: 0.9421 - val_loss: 0.7353 - val_accuracy: 0.8158
#
# Epoch 01171: val_loss improved from 0.73538 to 0.73532, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1172/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3132 - accuracy: 0.9395 - val_loss: 0.7353 - val_accuracy: 0.8158
#
# Epoch 01172: val_loss did not improve from 0.73532
# Epoch 1173/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3107 - accuracy: 0.9431 - val_loss: 0.7353 - val_accuracy: 0.8143
#
# Epoch 01173: val_loss improved from 0.73532 to 0.73526, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1174/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3096 - accuracy: 0.9448 - val_loss: 0.7351 - val_accuracy: 0.8143
#
# Epoch 01174: val_loss improved from 0.73526 to 0.73514, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1175/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3155 - accuracy: 0.9379 - val_loss: 0.7350 - val_accuracy: 0.8143
#
# Epoch 01175: val_loss improved from 0.73514 to 0.73503, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1176/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3130 - accuracy: 0.9390 - val_loss: 0.7350 - val_accuracy: 0.8158
#
# Epoch 01176: val_loss improved from 0.73503 to 0.73499, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1177/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3168 - accuracy: 0.9375 - val_loss: 0.7349 - val_accuracy: 0.8158
#
# Epoch 01177: val_loss improved from 0.73499 to 0.73491, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1178/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3096 - accuracy: 0.9418 - val_loss: 0.7348 - val_accuracy: 0.8158
#
# Epoch 01178: val_loss improved from 0.73491 to 0.73480, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1179/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3029 - accuracy: 0.9472 - val_loss: 0.7348 - val_accuracy: 0.8158
#
# Epoch 01179: val_loss improved from 0.73480 to 0.73477, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1180/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3090 - accuracy: 0.9413 - val_loss: 0.7347 - val_accuracy: 0.8158
#
# Epoch 01180: val_loss improved from 0.73477 to 0.73473, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1181/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3187 - accuracy: 0.9386 - val_loss: 0.7345 - val_accuracy: 0.8158
#
# Epoch 01181: val_loss improved from 0.73473 to 0.73454, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1182/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3075 - accuracy: 0.9447 - val_loss: 0.7345 - val_accuracy: 0.8158
#
# Epoch 01182: val_loss improved from 0.73454 to 0.73451, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1183/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3103 - accuracy: 0.9404 - val_loss: 0.7345 - val_accuracy: 0.8158
#
# Epoch 01183: val_loss improved from 0.73451 to 0.73448, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1184/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3148 - accuracy: 0.9392 - val_loss: 0.7343 - val_accuracy: 0.8158
#
# Epoch 01184: val_loss improved from 0.73448 to 0.73432, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1185/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3198 - accuracy: 0.9402 - val_loss: 0.7344 - val_accuracy: 0.8158
#
# Epoch 01185: val_loss did not improve from 0.73432
# Epoch 1186/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3053 - accuracy: 0.9426 - val_loss: 0.7342 - val_accuracy: 0.8158
#
# Epoch 01186: val_loss improved from 0.73432 to 0.73423, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1187/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3106 - accuracy: 0.9414 - val_loss: 0.7341 - val_accuracy: 0.8158
#
# Epoch 01187: val_loss improved from 0.73423 to 0.73413, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1188/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3061 - accuracy: 0.9418 - val_loss: 0.7341 - val_accuracy: 0.8158
#
# Epoch 01188: val_loss improved from 0.73413 to 0.73410, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1189/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3117 - accuracy: 0.9402 - val_loss: 0.7341 - val_accuracy: 0.8158
#
# Epoch 01189: val_loss improved from 0.73410 to 0.73405, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1190/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3097 - accuracy: 0.9415 - val_loss: 0.7339 - val_accuracy: 0.8158
#
# Epoch 01190: val_loss improved from 0.73405 to 0.73386, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1191/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3070 - accuracy: 0.9432 - val_loss: 0.7338 - val_accuracy: 0.8158
#
# Epoch 01191: val_loss improved from 0.73386 to 0.73383, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1192/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3046 - accuracy: 0.9440 - val_loss: 0.7338 - val_accuracy: 0.8158
#
# Epoch 01192: val_loss improved from 0.73383 to 0.73383, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1193/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3045 - accuracy: 0.9451 - val_loss: 0.7337 - val_accuracy: 0.8158
#
# Epoch 01193: val_loss improved from 0.73383 to 0.73365, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1194/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3123 - accuracy: 0.9422 - val_loss: 0.7335 - val_accuracy: 0.8158
#
# Epoch 01194: val_loss improved from 0.73365 to 0.73349, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1195/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3032 - accuracy: 0.9470 - val_loss: 0.7334 - val_accuracy: 0.8158
#
# Epoch 01195: val_loss improved from 0.73349 to 0.73342, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1196/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3066 - accuracy: 0.9431 - val_loss: 0.7333 - val_accuracy: 0.8158
#
# Epoch 01196: val_loss improved from 0.73342 to 0.73333, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1197/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3106 - accuracy: 0.9436 - val_loss: 0.7332 - val_accuracy: 0.8158
#
# Epoch 01197: val_loss improved from 0.73333 to 0.73315, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1198/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3037 - accuracy: 0.9423 - val_loss: 0.7331 - val_accuracy: 0.8158
#
# Epoch 01198: val_loss improved from 0.73315 to 0.73309, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1199/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3097 - accuracy: 0.9424 - val_loss: 0.7330 - val_accuracy: 0.8158
#
# Epoch 01199: val_loss improved from 0.73309 to 0.73298, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1200/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3135 - accuracy: 0.9391 - val_loss: 0.7328 - val_accuracy: 0.8143
#
# Epoch 01200: val_loss improved from 0.73298 to 0.73280, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1201/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3094 - accuracy: 0.9439 - val_loss: 0.7327 - val_accuracy: 0.8143
#
# Epoch 01201: val_loss improved from 0.73280 to 0.73270, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1202/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3112 - accuracy: 0.9427 - val_loss: 0.7326 - val_accuracy: 0.8143
#
# Epoch 01202: val_loss improved from 0.73270 to 0.73263, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1203/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3101 - accuracy: 0.9406 - val_loss: 0.7326 - val_accuracy: 0.8143
#
# Epoch 01203: val_loss improved from 0.73263 to 0.73257, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1204/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3087 - accuracy: 0.9446 - val_loss: 0.7325 - val_accuracy: 0.8143
#
# Epoch 01204: val_loss improved from 0.73257 to 0.73246, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1205/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3137 - accuracy: 0.9410 - val_loss: 0.7323 - val_accuracy: 0.8143
#
# Epoch 01205: val_loss improved from 0.73246 to 0.73235, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1206/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3075 - accuracy: 0.9401 - val_loss: 0.7321 - val_accuracy: 0.8143
#
# Epoch 01206: val_loss improved from 0.73235 to 0.73215, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1207/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3097 - accuracy: 0.9411 - val_loss: 0.7321 - val_accuracy: 0.8143
#
# Epoch 01207: val_loss improved from 0.73215 to 0.73207, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1208/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3029 - accuracy: 0.9427 - val_loss: 0.7320 - val_accuracy: 0.8143
#
# Epoch 01208: val_loss improved from 0.73207 to 0.73198, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1209/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3147 - accuracy: 0.9395 - val_loss: 0.7319 - val_accuracy: 0.8143
#
# Epoch 01209: val_loss improved from 0.73198 to 0.73188, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1210/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3121 - accuracy: 0.9417 - val_loss: 0.7318 - val_accuracy: 0.8143
#
# Epoch 01210: val_loss improved from 0.73188 to 0.73184, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1211/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3056 - accuracy: 0.9469 - val_loss: 0.7317 - val_accuracy: 0.8143
#
# Epoch 01211: val_loss improved from 0.73184 to 0.73170, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1212/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3145 - accuracy: 0.9410 - val_loss: 0.7316 - val_accuracy: 0.8143
#
# Epoch 01212: val_loss improved from 0.73170 to 0.73161, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1213/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3034 - accuracy: 0.9433 - val_loss: 0.7315 - val_accuracy: 0.8143
#
# Epoch 01213: val_loss improved from 0.73161 to 0.73155, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1214/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3146 - accuracy: 0.9410 - val_loss: 0.7315 - val_accuracy: 0.8158
#
# Epoch 01214: val_loss improved from 0.73155 to 0.73151, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 1215/2000
# 131/509 [======>.......................] - ETA: 0s - loss: 0.3071 - accuracy: 0.9384

# %%
best_hps=tuner.get_best_models(1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(1)[0]
best_hyperparameters.values
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 768)]             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              787456
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 219)               224475
# =================================================================
# Total params: 1,011,931
# Trainable params: 1,011,931
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'units': 1024, 'rate': 0.5, 'lr': 5.340180261128443e-05}

# %% [markdown]
# # 以最佳模型參數建立模型

# %%
# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('lr')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 1024 and the optimal learning rate for the optimizer
# is 5.340180261128443e-05.

# %%
# Build the model with the optimal hyperparameters 
# 用最佳參數找出最佳epoch
model = tuner.hypermodel.build(best_hps)
history = model.fit(train_features, train_labels_OH, 
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = True,
                    callbacks = [checkpoint, earlystop],
                    validation_data = (val_features, val_labels_OH),
                    steps_per_epoch=steps_per_epoch)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 768)]             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              787456
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 219)               224475
# =================================================================
# Total params: 1,011,931
# Trainable params: 1,011,931
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2000
# 509/509 [==============================] - 2s 3ms/step - loss: 5.2715 - accuracy: 0.0237 - val_loss: 4.1133 - val_accuracy: 0.2374
#
# Epoch 00001: val_loss improved from inf to 4.11327, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 2/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 3.8654 - accuracy: 0.1878 - val_loss: 3.1597 - val_accuracy: 0.4201
#
# Epoch 00002: val_loss improved from 4.11327 to 3.15974, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 3/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 2.9398 - accuracy: 0.3654 - val_loss: 2.5861 - val_accuracy: 0.5312
#
# Epoch 00003: val_loss improved from 3.15974 to 2.58608, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 4/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 2.3566 - accuracy: 0.4832 - val_loss: 2.2105 - val_accuracy: 0.5967
#
# Epoch 00004: val_loss improved from 2.58608 to 2.21047, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 5/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.9497 - accuracy: 0.5751 - val_loss: 1.9364 - val_accuracy: 0.6530
#
# Epoch 00005: val_loss improved from 2.21047 to 1.93639, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 6/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.6592 - accuracy: 0.6384 - val_loss: 1.7454 - val_accuracy: 0.6758
#
# Epoch 00006: val_loss improved from 1.93639 to 1.74541, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 7/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.4515 - accuracy: 0.6809 - val_loss: 1.5906 - val_accuracy: 0.6758
#
# Epoch 00007: val_loss improved from 1.74541 to 1.59059, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 8/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 1.2697 - accuracy: 0.7277 - val_loss: 1.4659 - val_accuracy: 0.6865
#
# Epoch 00008: val_loss improved from 1.59059 to 1.46591, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 9/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1257 - accuracy: 0.7642 - val_loss: 1.3635 - val_accuracy: 0.7093
#
# Epoch 00009: val_loss improved from 1.46591 to 1.36351, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 10/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 1.0175 - accuracy: 0.7803 - val_loss: 1.2810 - val_accuracy: 0.7169
#
# Epoch 00010: val_loss improved from 1.36351 to 1.28102, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 11/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9139 - accuracy: 0.8039 - val_loss: 1.2082 - val_accuracy: 0.7367
#
# Epoch 00011: val_loss improved from 1.28102 to 1.20823, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 12/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8300 - accuracy: 0.8283 - val_loss: 1.1531 - val_accuracy: 0.7291
#
# Epoch 00012: val_loss improved from 1.20823 to 1.15306, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 13/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.7593 - accuracy: 0.8432 - val_loss: 1.0937 - val_accuracy: 0.7458
#
# Epoch 00013: val_loss improved from 1.15306 to 1.09371, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 14/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.6995 - accuracy: 0.8522 - val_loss: 1.0551 - val_accuracy: 0.7504
#
# Epoch 00014: val_loss improved from 1.09371 to 1.05509, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 15/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.6456 - accuracy: 0.8672 - val_loss: 1.0126 - val_accuracy: 0.7504
#
# Epoch 00015: val_loss improved from 1.05509 to 1.01258, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 16/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.5887 - accuracy: 0.8852 - val_loss: 0.9738 - val_accuracy: 0.7626
#
# Epoch 00016: val_loss improved from 1.01258 to 0.97379, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 17/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.5550 - accuracy: 0.8926 - val_loss: 0.9407 - val_accuracy: 0.7763
#
# Epoch 00017: val_loss improved from 0.97379 to 0.94070, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 18/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.5122 - accuracy: 0.9015 - val_loss: 0.9195 - val_accuracy: 0.7702
#
# Epoch 00018: val_loss improved from 0.94070 to 0.91947, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 19/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.4844 - accuracy: 0.9078 - val_loss: 0.8957 - val_accuracy: 0.7732
#
# Epoch 00019: val_loss improved from 0.91947 to 0.89570, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 20/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.4475 - accuracy: 0.9143 - val_loss: 0.8627 - val_accuracy: 0.7793
#
# Epoch 00020: val_loss improved from 0.89570 to 0.86266, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 21/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.4272 - accuracy: 0.9176 - val_loss: 0.8510 - val_accuracy: 0.7839
#
# Epoch 00021: val_loss improved from 0.86266 to 0.85099, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 22/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.4082 - accuracy: 0.9237 - val_loss: 0.8316 - val_accuracy: 0.7884
#
# Epoch 00022: val_loss improved from 0.85099 to 0.83164, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 23/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3754 - accuracy: 0.9330 - val_loss: 0.8116 - val_accuracy: 0.7991
#
# Epoch 00023: val_loss improved from 0.83164 to 0.81155, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 24/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3611 - accuracy: 0.9336 - val_loss: 0.8012 - val_accuracy: 0.7808
#
# Epoch 00024: val_loss improved from 0.81155 to 0.80122, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 25/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3429 - accuracy: 0.9357 - val_loss: 0.7849 - val_accuracy: 0.7991
# Epoch 00025: val_loss improved from 0.80122 to 0.78494, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 26/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3245 - accuracy: 0.9441 - val_loss: 0.7745 - val_accuracy: 0.8006
#
# Epoch 00026: val_loss improved from 0.78494 to 0.77447, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 27/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3128 - accuracy: 0.9404 - val_loss: 0.7581 - val_accuracy: 0.8037
#
# Epoch 00027: val_loss improved from 0.77447 to 0.75810, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 28/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3009 - accuracy: 0.9491 - val_loss: 0.7504 - val_accuracy: 0.8021
#
# Epoch 00028: val_loss improved from 0.75810 to 0.75041, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 29/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2886 - accuracy: 0.9468 - val_loss: 0.7367 - val_accuracy: 0.8067
#
# Epoch 00029: val_loss improved from 0.75041 to 0.73673, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 30/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2605 - accuracy: 0.9564 - val_loss: 0.7315 - val_accuracy: 0.7991
#
# Epoch 00030: val_loss improved from 0.73673 to 0.73154, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 31/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2660 - accuracy: 0.9524 - val_loss: 0.7218 - val_accuracy: 0.8052
#
# Epoch 00031: val_loss improved from 0.73154 to 0.72184, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 32/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2518 - accuracy: 0.9565 - val_loss: 0.7136 - val_accuracy: 0.8021
#
# Epoch 00032: val_loss improved from 0.72184 to 0.71356, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 33/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2392 - accuracy: 0.9611 - val_loss: 0.7088 - val_accuracy: 0.8037
#
# Epoch 00033: val_loss improved from 0.71356 to 0.70880, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 34/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2350 - accuracy: 0.9595 - val_loss: 0.7029 - val_accuracy: 0.8021
#
# Epoch 00034: val_loss improved from 0.70880 to 0.70286, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 35/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2218 - accuracy: 0.9650 - val_loss: 0.6977 - val_accuracy: 0.8067
#
# Epoch 00035: val_loss improved from 0.70286 to 0.69769, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 36/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2170 - accuracy: 0.9622 - val_loss: 0.6860 - val_accuracy: 0.8189
#
# Epoch 00036: val_loss improved from 0.69769 to 0.68601, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 37/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2025 - accuracy: 0.9679 - val_loss: 0.6802 - val_accuracy: 0.8174
#
# Epoch 00037: val_loss improved from 0.68601 to 0.68025, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 38/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1986 - accuracy: 0.9673 - val_loss: 0.6813 - val_accuracy: 0.8128
#
# Epoch 00038: val_loss did not improve from 0.68025
# Epoch 39/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1945 - accuracy: 0.9671 - val_loss: 0.6736 - val_accuracy: 0.8189
#
# Epoch 00039: val_loss improved from 0.68025 to 0.67364, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 40/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1879 - accuracy: 0.9683 - val_loss: 0.6651 - val_accuracy: 0.8204
#
# Epoch 00040: val_loss improved from 0.67364 to 0.66514, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 41/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1797 - accuracy: 0.9718 - val_loss: 0.6585 - val_accuracy: 0.8250
#
# Epoch 00041: val_loss improved from 0.66514 to 0.65848, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 42/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1768 - accuracy: 0.9719 - val_loss: 0.6533 - val_accuracy: 0.8219
#
# Epoch 00042: val_loss improved from 0.65848 to 0.65325, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 43/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1633 - accuracy: 0.9762 - val_loss: 0.6538 - val_accuracy: 0.8204
#
# Epoch 00043: val_loss did not improve from 0.65325
# Epoch 44/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1627 - accuracy: 0.9747 - val_loss: 0.6508 - val_accuracy: 0.8219
#
# Epoch 00044: val_loss improved from 0.65325 to 0.65075, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 45/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1656 - accuracy: 0.9727 - val_loss: 0.6448 - val_accuracy: 0.8234
#
# Epoch 00045: val_loss improved from 0.65075 to 0.64482, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 46/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1527 - accuracy: 0.9781 - val_loss: 0.6369 - val_accuracy: 0.8219
#
# Epoch 00046: val_loss improved from 0.64482 to 0.63689, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 47/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1608 - accuracy: 0.9742 - val_loss: 0.6358 - val_accuracy: 0.8295
#
# Epoch 00047: val_loss improved from 0.63689 to 0.63577, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 48/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1476 - accuracy: 0.9780 - val_loss: 0.6357 - val_accuracy: 0.8295
#
# Epoch 00048: val_loss improved from 0.63577 to 0.63566, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 49/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1414 - accuracy: 0.9801 - val_loss: 0.6364 - val_accuracy: 0.8204
#
# Epoch 00049: val_loss did not improve from 0.63566
# Epoch 50/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1410 - accuracy: 0.9804 - val_loss: 0.6311 - val_accuracy: 0.8265
#
# Epoch 00050: val_loss improved from 0.63566 to 0.63114, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 51/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1339 - accuracy: 0.9812 - val_loss: 0.6249 - val_accuracy: 0.8265
#
# Epoch 00051: val_loss improved from 0.63114 to 0.62493, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 52/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1335 - accuracy: 0.9806 - val_loss: 0.6238 - val_accuracy: 0.8250
#
# Epoch 00052: val_loss improved from 0.62493 to 0.62382, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 53/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1321 - accuracy: 0.9796 - val_loss: 0.6248 - val_accuracy: 0.8326
#
# Epoch 00053: val_loss did not improve from 0.62382
# Epoch 54/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1233 - accuracy: 0.9836 - val_loss: 0.6219 - val_accuracy: 0.8341
#
# Epoch 00054: val_loss improved from 0.62382 to 0.62194, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 55/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1277 - accuracy: 0.9799 - val_loss: 0.6146 - val_accuracy: 0.8311
#
# Epoch 00055: val_loss improved from 0.62194 to 0.61461, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 56/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1167 - accuracy: 0.9839 - val_loss: 0.6148 - val_accuracy: 0.8280
#
# Epoch 00056: val_loss did not improve from 0.61461
# Epoch 57/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1229 - accuracy: 0.9804 - val_loss: 0.6126 - val_accuracy: 0.8326
#
# Epoch 00057: val_loss improved from 0.61461 to 0.61259, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 58/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1154 - accuracy: 0.9829 - val_loss: 0.6156 - val_accuracy: 0.8250
#
# Epoch 00058: val_loss did not improve from 0.61259
# Epoch 59/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1119 - accuracy: 0.9858 - val_loss: 0.6111 - val_accuracy: 0.8280
#
# Epoch 00059: val_loss improved from 0.61259 to 0.61110, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 60/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1069 - accuracy: 0.9852 - val_loss: 0.6037 - val_accuracy: 0.8311
#
# Epoch 00060: val_loss improved from 0.61110 to 0.60372, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 61/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1079 - accuracy: 0.9833 - val_loss: 0.6056 - val_accuracy: 0.8295
#
# Epoch 00061: val_loss did not improve from 0.60372
# Epoch 62/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1055 - accuracy: 0.9866 - val_loss: 0.6043 - val_accuracy: 0.8326
#
# Epoch 00062: val_loss did not improve from 0.60372
# Epoch 63/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1038 - accuracy: 0.9868 - val_loss: 0.6018 - val_accuracy: 0.8341
#
# Epoch 00063: val_loss improved from 0.60372 to 0.60180, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 64/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0975 - accuracy: 0.9893 - val_loss: 0.5965 - val_accuracy: 0.8295
#
# Epoch 00064: val_loss improved from 0.60180 to 0.59653, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 65/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1000 - accuracy: 0.9872 - val_loss: 0.6004 - val_accuracy: 0.8326
#
# Epoch 00065: val_loss did not improve from 0.59653
# Epoch 66/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0968 - accuracy: 0.9877 - val_loss: 0.5992 - val_accuracy: 0.8311
#
# Epoch 00066: val_loss did not improve from 0.59653
# Epoch 67/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0990 - accuracy: 0.9871 - val_loss: 0.5949 - val_accuracy: 0.8326
#
# Epoch 00067: val_loss improved from 0.59653 to 0.59485, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 68/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0942 - accuracy: 0.9874 - val_loss: 0.5979 - val_accuracy: 0.8311
#
# Epoch 00068: val_loss did not improve from 0.59485
# Epoch 69/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0940 - accuracy: 0.9875 - val_loss: 0.5947 - val_accuracy: 0.8356
#
# Epoch 00069: val_loss improved from 0.59485 to 0.59469, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 70/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0905 - accuracy: 0.9897 - val_loss: 0.5977 - val_accuracy: 0.8356
#
# Epoch 00070: val_loss did not improve from 0.59469
# Epoch 71/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0897 - accuracy: 0.9894 - val_loss: 0.5943 - val_accuracy: 0.8356
#
# Epoch 00071: val_loss improved from 0.59469 to 0.59433, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 72/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0845 - accuracy: 0.9895 - val_loss: 0.5909 - val_accuracy: 0.8295
#
# Epoch 00072: val_loss improved from 0.59433 to 0.59094, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 73/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0839 - accuracy: 0.9888 - val_loss: 0.5921 - val_accuracy: 0.8371
#
# Epoch 00073: val_loss did not improve from 0.59094
# Epoch 74/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0807 - accuracy: 0.9914 - val_loss: 0.5886 - val_accuracy: 0.8326
#
# Epoch 00074: val_loss improved from 0.59094 to 0.58861, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 75/2000
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0833 - accuracy: 0.9904 - val_loss: 0.5882 - val_accuracy: 0.8356
#
# Epoch 00075: val_loss improved from 0.58861 to 0.58819, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 76/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0802 - accuracy: 0.9903 - val_loss: 0.5884 - val_accuracy: 0.8387
#
# Epoch 00076: val_loss did not improve from 0.58819
# Epoch 77/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0774 - accuracy: 0.9910 - val_loss: 0.5899 - val_accuracy: 0.8371
#
# Epoch 00077: val_loss did not improve from 0.58819
# Epoch 78/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0761 - accuracy: 0.9913 - val_loss: 0.5853 - val_accuracy: 0.8387
#
# Epoch 00078: val_loss improved from 0.58819 to 0.58531, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 79/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0762 - accuracy: 0.9904 - val_loss: 0.5867 - val_accuracy: 0.8341
#
# Epoch 00079: val_loss did not improve from 0.58531
# Epoch 80/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0788 - accuracy: 0.9899 - val_loss: 0.5823 - val_accuracy: 0.8326
#
# Epoch 00080: val_loss improved from 0.58531 to 0.58232, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 81/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0761 - accuracy: 0.9905 - val_loss: 0.5817 - val_accuracy: 0.8341
#
# Epoch 00081: val_loss improved from 0.58232 to 0.58172, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 82/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0711 - accuracy: 0.9926 - val_loss: 0.5782 - val_accuracy: 0.8341
#
# Epoch 00082: val_loss improved from 0.58172 to 0.57821, saving model to /tf/TBrain_Orchid_Recognition/Orchid_Recognition/saved_models/Model_CLIP.h5
# Epoch 83/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0746 - accuracy: 0.9906 - val_loss: 0.5819 - val_accuracy: 0.8371
#
# Epoch 00083: val_loss did not improve from 0.57821
# Epoch 84/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0758 - accuracy: 0.9909 - val_loss: 0.5841 - val_accuracy: 0.8371
#
# Epoch 00084: val_loss did not improve from 0.57821
# Epoch 85/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0702 - accuracy: 0.9921 - val_loss: 0.5845 - val_accuracy: 0.8356
#
# Epoch 00085: val_loss did not improve from 0.57821
# Epoch 86/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0693 - accuracy: 0.9925 - val_loss: 0.5846 - val_accuracy: 0.8341
#
# Epoch 00086: val_loss did not improve from 0.57821
# Epoch 87/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0703 - accuracy: 0.9916 - val_loss: 0.5811 - val_accuracy: 0.8311
#
# Epoch 00087: val_loss did not improve from 0.57821
# Epoch 88/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0686 - accuracy: 0.9921 - val_loss: 0.5818 - val_accuracy: 0.8356
# Epoch 00088: val_loss did not improve from 0.57821
# Epoch 89/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0669 - accuracy: 0.9926 - val_loss: 0.5807 - val_accuracy: 0.8356
#
# Epoch 00089: val_loss did not improve from 0.57821
# Epoch 90/2000
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0638 - accuracy: 0.9935 - val_loss: 0.5831 - val_accuracy: 0.8311
#
# Epoch 00090: val_loss did not improve from 0.57821
# Epoch 91/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0644 - accuracy: 0.9926 - val_loss: 0.5804 - val_accuracy: 0.8371
#
# Epoch 00091: val_loss did not improve from 0.57821
# Epoch 92/2000
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0637 - accuracy: 0.9939 - val_loss: 0.5816 - val_accuracy: 0.8341
#
# Epoch 00092: val_loss did not improve from 0.57821
# Epoch 00092: early stopping
# Best epoch: 76

# %%
# 訓練最佳epoch數量
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
history = hypermodel.fit(train_features, train_labels_OH, 
                         batch_size = batch_size,
                         epochs = best_epoch,
                         verbose = True,
                         callbacks = [checkpoint],
                         validation_data = (val_features, val_labels_OH),
                         steps_per_epoch=steps_per_epoch)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 768)]             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              787456
# _________________________________________________________________
# activation_2 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 219)               224475
# =================================================================
# Total params: 1,011,931
# Trainable params: 1,011,931
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/76
# 509/509 [==============================] - 2s 3ms/step - loss: 5.2674 - accuracy: 0.0268 - val_loss: 4.0714 - val_accuracy: 0.2359
#
# Epoch 00001: val_loss did not improve from 0.57821
# Epoch 2/76
# 509/509 [==============================] - 1s 2ms/step - loss: 3.8459 - accuracy: 0.2021 - val_loss: 3.1265 - val_accuracy: 0.4201
#
# Epoch 00002: val_loss did not improve from 0.57821
# Epoch 3/76
# 509/509 [==============================] - 1s 3ms/step - loss: 2.9112 - accuracy: 0.3721 - val_loss: 2.5444 - val_accuracy: 0.5723
#
# Epoch 00003: val_loss did not improve from 0.57821
# Epoch 4/76
# 509/509 [==============================] - 1s 3ms/step - loss: 2.3380 - accuracy: 0.4864 - val_loss: 2.1799 - val_accuracy: 0.6164
#
# Epoch 00004: val_loss did not improve from 0.57821
# Epoch 5/76
# 509/509 [==============================] - 1s 2ms/step - loss: 1.9442 - accuracy: 0.5785 - val_loss: 1.9134 - val_accuracy: 0.6469
#
# Epoch 00005: val_loss did not improve from 0.57821
# Epoch 6/76
# 509/509 [==============================] - 1s 3ms/step - loss: 1.6497 - accuracy: 0.6442 - val_loss: 1.7224 - val_accuracy: 0.6682
#
# Epoch 00006: val_loss did not improve from 0.57821
# Epoch 7/76
# 509/509 [==============================] - 1s 2ms/step - loss: 1.4352 - accuracy: 0.6875 - val_loss: 1.5655 - val_accuracy: 0.6834
#
# Epoch 00007: val_loss did not improve from 0.57821
# Epoch 8/76
# 509/509 [==============================] - 1s 2ms/step - loss: 1.2505 - accuracy: 0.7331 - val_loss: 1.4446 - val_accuracy: 0.7017
#
# Epoch 00008: val_loss did not improve from 0.57821
# Epoch 9/76
# 509/509 [==============================] - 1s 2ms/step - loss: 1.1086 - accuracy: 0.7596 - val_loss: 1.3489 - val_accuracy: 0.7139
#
# Epoch 00009: val_loss did not improve from 0.57821
# Epoch 10/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.9964 - accuracy: 0.7927 - val_loss: 1.2642 - val_accuracy: 0.7245
#
# Epoch 00010: val_loss did not improve from 0.57821
# Epoch 11/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.8990 - accuracy: 0.8138 - val_loss: 1.1918 - val_accuracy: 0.7412
#
# Epoch 00011: val_loss did not improve from 0.57821
# Epoch 12/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.8136 - accuracy: 0.8349 - val_loss: 1.1332 - val_accuracy: 0.7519
#
# Epoch 00012: val_loss did not improve from 0.57821
# Epoch 13/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.7484 - accuracy: 0.8480 - val_loss: 1.0871 - val_accuracy: 0.7549
#
# Epoch 00013: val_loss did not improve from 0.57821
# Epoch 14/76
# 509/509 [==============================] - 2s 3ms/step - loss: 0.6783 - accuracy: 0.8670 - val_loss: 1.0336 - val_accuracy: 0.7626
#
# Epoch 00014: val_loss did not improve from 0.57821
# Epoch 15/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.6424 - accuracy: 0.8713 - val_loss: 1.0010 - val_accuracy: 0.7671
#
# Epoch 00015: val_loss did not improve from 0.57821
# Epoch 16/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.5836 - accuracy: 0.8871 - val_loss: 0.9625 - val_accuracy: 0.7778
#
# Epoch 00016: val_loss did not improve from 0.57821
# Epoch 17/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.5589 - accuracy: 0.8898 - val_loss: 0.9405 - val_accuracy: 0.7702
#
# Epoch 00017: val_loss did not improve from 0.57821
# Epoch 18/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.5063 - accuracy: 0.9029 - val_loss: 0.9107 - val_accuracy: 0.7808
#
# Epoch 00018: val_loss did not improve from 0.57821
# Epoch 19/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.4689 - accuracy: 0.9100 - val_loss: 0.8806 - val_accuracy: 0.7854
#
# Epoch 00019: val_loss did not improve from 0.57821
# Epoch 20/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.4597 - accuracy: 0.9076 - val_loss: 0.8636 - val_accuracy: 0.7763
#
# Epoch 00020: val_loss did not improve from 0.57821
# Epoch 21/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.4315 - accuracy: 0.9127 - val_loss: 0.8431 - val_accuracy: 0.7808
#
# Epoch 00021: val_loss did not improve from 0.57821
# Epoch 22/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3860 - accuracy: 0.9287 - val_loss: 0.8196 - val_accuracy: 0.7976
#
# Epoch 00022: val_loss did not improve from 0.57821
# Epoch 23/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3750 - accuracy: 0.9321 - val_loss: 0.8094 - val_accuracy: 0.7823
#
# Epoch 00023: val_loss did not improve from 0.57821
# Epoch 24/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3619 - accuracy: 0.9344 - val_loss: 0.7936 - val_accuracy: 0.7976
#
# Epoch 00024: val_loss did not improve from 0.57821
# Epoch 25/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3308 - accuracy: 0.9427 - val_loss: 0.7751 - val_accuracy: 0.7945
#
# Epoch 00025: val_loss did not improve from 0.57821
# Epoch 26/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.3208 - accuracy: 0.9454 - val_loss: 0.7677 - val_accuracy: 0.8037
#
# Epoch 00026: val_loss did not improve from 0.57821
# Epoch 27/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.3010 - accuracy: 0.9494 - val_loss: 0.7607 - val_accuracy: 0.7960
#
# Epoch 00027: val_loss did not improve from 0.57821
# Epoch 28/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2868 - accuracy: 0.9488 - val_loss: 0.7446 - val_accuracy: 0.8021
#
# Epoch 00028: val_loss did not improve from 0.57821
# Epoch 29/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2797 - accuracy: 0.9509 - val_loss: 0.7346 - val_accuracy: 0.8082
#
# Epoch 00029: val_loss did not improve from 0.57821
# Epoch 30/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2645 - accuracy: 0.9563 - val_loss: 0.7261 - val_accuracy: 0.8067
#
# Epoch 00030: val_loss did not improve from 0.57821
# Epoch 31/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2581 - accuracy: 0.9565 - val_loss: 0.7158 - val_accuracy: 0.8113
#
# Epoch 00031: val_loss did not improve from 0.57821
# Epoch 32/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2517 - accuracy: 0.9566 - val_loss: 0.7093 - val_accuracy: 0.8082
#
# Epoch 00032: val_loss did not improve from 0.57821
# Epoch 33/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2320 - accuracy: 0.9617 - val_loss: 0.6961 - val_accuracy: 0.8128
#
# Epoch 00033: val_loss did not improve from 0.57821
# Epoch 34/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2304 - accuracy: 0.9640 - val_loss: 0.6924 - val_accuracy: 0.8143
#
# Epoch 00034: val_loss did not improve from 0.57821
# Epoch 35/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2139 - accuracy: 0.9669 - val_loss: 0.6846 - val_accuracy: 0.8128
#
# Epoch 00035: val_loss did not improve from 0.57821
# Epoch 36/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.2167 - accuracy: 0.9641 - val_loss: 0.6784 - val_accuracy: 0.8158
#
# Epoch 00036: val_loss did not improve from 0.57821
# Epoch 37/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2043 - accuracy: 0.9641 - val_loss: 0.6723 - val_accuracy: 0.8250
#
# Epoch 00037: val_loss did not improve from 0.57821
# Epoch 38/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.2020 - accuracy: 0.9668 - val_loss: 0.6670 - val_accuracy: 0.8128
#
# Epoch 00038: val_loss did not improve from 0.57821
# Epoch 39/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1915 - accuracy: 0.9694 - val_loss: 0.6623 - val_accuracy: 0.8189
#
# Epoch 00039: val_loss did not improve from 0.57821
# Epoch 40/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1905 - accuracy: 0.9710 - val_loss: 0.6561 - val_accuracy: 0.8128
#
# Epoch 00040: val_loss did not improve from 0.57821
# Epoch 41/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1742 - accuracy: 0.9721 - val_loss: 0.6529 - val_accuracy: 0.8234
#
# Epoch 00041: val_loss did not improve from 0.57821
# Epoch 42/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1787 - accuracy: 0.9693 - val_loss: 0.6485 - val_accuracy: 0.8250
#
# Epoch 00042: val_loss did not improve from 0.57821
# Epoch 43/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1699 - accuracy: 0.9740 - val_loss: 0.6483 - val_accuracy: 0.8234
#
# Epoch 00043: val_loss did not improve from 0.57821
# Epoch 44/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1679 - accuracy: 0.9741 - val_loss: 0.6448 - val_accuracy: 0.8250
#
# Epoch 00044: val_loss did not improve from 0.57821
# Epoch 45/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1553 - accuracy: 0.9758 - val_loss: 0.6373 - val_accuracy: 0.8250
#
# Epoch 00045: val_loss did not improve from 0.57821
# Epoch 46/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1514 - accuracy: 0.9795 - val_loss: 0.6384 - val_accuracy: 0.8280
#
# Epoch 00046: val_loss did not improve from 0.57821
# Epoch 47/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1471 - accuracy: 0.9792 - val_loss: 0.6331 - val_accuracy: 0.8265
#
# Epoch 00047: val_loss did not improve from 0.57821
# Epoch 48/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1435 - accuracy: 0.9783 - val_loss: 0.6291 - val_accuracy: 0.8295
#
# Epoch 00048: val_loss did not improve from 0.57821
# Epoch 49/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1429 - accuracy: 0.9817 - val_loss: 0.6227 - val_accuracy: 0.8295
#
# Epoch 00049: val_loss did not improve from 0.57821
# Epoch 50/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1343 - accuracy: 0.9817 - val_loss: 0.6227 - val_accuracy: 0.8265
#
# Epoch 00050: val_loss did not improve from 0.57821
# Epoch 51/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9797 - val_loss: 0.6265 - val_accuracy: 0.8234
#
# Epoch 00051: val_loss did not improve from 0.57821
# Epoch 52/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1325 - accuracy: 0.9809 - val_loss: 0.6219 - val_accuracy: 0.8250
#
# Epoch 00052: val_loss did not improve from 0.57821
# Epoch 53/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1276 - accuracy: 0.9814 - val_loss: 0.6145 - val_accuracy: 0.8265
#
# Epoch 00053: val_loss did not improve from 0.57821
# Epoch 54/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1258 - accuracy: 0.9816 - val_loss: 0.6138 - val_accuracy: 0.8326
#
# Epoch 00054: val_loss did not improve from 0.57821
# Epoch 55/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1252 - accuracy: 0.9823 - val_loss: 0.6137 - val_accuracy: 0.8280
#
# Epoch 00055: val_loss did not improve from 0.57821
# Epoch 56/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1171 - accuracy: 0.9867 - val_loss: 0.6100 - val_accuracy: 0.8250
#
# Epoch 00056: val_loss did not improve from 0.57821
# Epoch 57/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1136 - accuracy: 0.9854 - val_loss: 0.6084 - val_accuracy: 0.8326
#
# Epoch 00057: val_loss did not improve from 0.57821
# Epoch 58/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1112 - accuracy: 0.9869 - val_loss: 0.6024 - val_accuracy: 0.8265
#
# Epoch 00058: val_loss did not improve from 0.57821
# Epoch 59/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1108 - accuracy: 0.9850 - val_loss: 0.6024 - val_accuracy: 0.8295
#
# Epoch 00059: val_loss did not improve from 0.57821
# Epoch 60/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.1098 - accuracy: 0.9834 - val_loss: 0.6029 - val_accuracy: 0.8326
#
# Epoch 00060: val_loss did not improve from 0.57821
# Epoch 61/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.9838 - val_loss: 0.6007 - val_accuracy: 0.8326
#
# Epoch 00061: val_loss did not improve from 0.57821
# Epoch 62/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1053 - accuracy: 0.9872 - val_loss: 0.5970 - val_accuracy: 0.8295
#
# Epoch 00062: val_loss did not improve from 0.57821
# Epoch 63/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1039 - accuracy: 0.9850 - val_loss: 0.5963 - val_accuracy: 0.8265
#
# Epoch 00063: val_loss did not improve from 0.57821
# Epoch 64/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0982 - accuracy: 0.9889 - val_loss: 0.5977 - val_accuracy: 0.8326
#
# Epoch 00064: val_loss did not improve from 0.57821
# Epoch 65/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.1035 - accuracy: 0.9849 - val_loss: 0.5973 - val_accuracy: 0.8326
#
# Epoch 00065: val_loss did not improve from 0.57821
# Epoch 66/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0943 - accuracy: 0.9893 - val_loss: 0.5946 - val_accuracy: 0.8311
#
# Epoch 00066: val_loss did not improve from 0.57821
# Epoch 67/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0973 - accuracy: 0.9873 - val_loss: 0.5946 - val_accuracy: 0.8295
#
# Epoch 00067: val_loss did not improve from 0.57821
# Epoch 68/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0937 - accuracy: 0.9874 - val_loss: 0.5901 - val_accuracy: 0.8341
#
# Epoch 00068: val_loss did not improve from 0.57821
# Epoch 69/76
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0948 - accuracy: 0.9866 - val_loss: 0.5887 - val_accuracy: 0.8295
#
# Epoch 00069: val_loss did not improve from 0.57821
# Epoch 70/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0898 - accuracy: 0.9883 - val_loss: 0.5915 - val_accuracy: 0.8265
#
# Epoch 00070: val_loss did not improve from 0.57821
# Epoch 71/76
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0913 - accuracy: 0.9881 - val_loss: 0.5882 - val_accuracy: 0.8295
#
# Epoch 00071: val_loss did not improve from 0.57821
# Epoch 72/76
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0849 - accuracy: 0.9893 - val_loss: 0.5878 - val_accuracy: 0.8356
#
# Epoch 00072: val_loss did not improve from 0.57821
# Epoch 73/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0860 - accuracy: 0.9909 - val_loss: 0.5871 - val_accuracy: 0.8311
#
# Epoch 00073: val_loss did not improve from 0.57821
# Epoch 74/76
# 509/509 [==============================] - 1s 3ms/step - loss: 0.0879 - accuracy: 0.9891 - val_loss: 0.5854 - val_accuracy: 0.8387
#
# Epoch 00074: val_loss did not improve from 0.57821
# Epoch 75/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0839 - accuracy: 0.9897 - val_loss: 0.5854 - val_accuracy: 0.8402
#
# Epoch 00075: val_loss did not improve from 0.57821
# Epoch 76/76
# 509/509 [==============================] - 1s 2ms/step - loss: 0.0799 - accuracy: 0.9907 - val_loss: 0.5815 - val_accuracy: 0.8371
#
# Epoch 00076: val_loss did not improve from 0.57821

# %%
eval_result = hypermodel.evaluate(val_features, val_labels_OH)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5815 - accuracy: 0.8371
# [test loss, test accuracy]: [0.5814616680145264, 0.8371385335922241]

# %%
final_model = keras.models.load_model('saved_models/Model_CLIP.h5')
scores = final_model.evaluate(val_features, val_labels_OH)
# Out:
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5782 - accuracy: 0.8341

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import classification_report
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
target_names = ['banana', 'bareland', 'carrot', 'corn', 'dragonfruit', 'garlic',
                'guava', 'inundated', 'peanut', 'pineapple', 'pumpkin', 'rice',
                'soybean', 'sugarcane', 'tomato']
print(classification_report(y_test, predictions, target_names=target_names))
print ("**************************************************************")

# %%
plt.style.use('seaborn-white')
plt.figure(figsize=(50, 20))
cnf_matrix = confusion_matrix(y_test, predictions)
plot_confusion_matrix(cnf_matrix, classes=target_names,normalize=True,
                    title='confusion matrix')

# %% [markdown]
# ## 實驗
# - DA5 : Data Augmentation with 5 num_iter (五倍資料量)
# - B32 : ViT_B32
# - train_test_split : 7:3
# - cv : 3
#
# ### BaseLine
# - NoDA, B/32, LG, iter=5000, C=0.9 : 70.9%
# - NoDA, L/14, LG, iter=5000, C=0.9 : 77.9%
#
#
# ### ViT_B/32
# - DA,  LG, iter=5000, C=0.9, No[ColorJitter] : 62.7%
# - DA2, LG, iter=5000, C=0.9, No[ColorJitter] : 68.49%
# - DA5, LG, iter=5000, C=0.9, No[ColorJitter] : 73.82%
# - DA10, LG, iter=5000, C=0.9, No[ColorJitter] : 75.95%
#
#
#
# ### ViT_L/14
# - DA,   LG, iter=5000, C=0.9, No[ColorJitter] : 68.9%
# - DA2,  LG, iter=5000, C=0.9, No[ColorJitter] : 75.19%
# - DA5,  LG, iter=5000, C=0.9, No[ColorJitter] : 80%
# - DA10, LG, iter-5000, C=0.9, No[ColorJitter] : 83.4%
# - DA5,  LG, iter-5000, C=0.9 : 78.9%
#
# ___
# ### Keras_ViT_L/14
# - DA10, Dense(1024), lr(5.34e-5), dropout(0.5) : 83.4%
# - DA10, Dense(4096), lr(1e-5),    dropout(0.5) : 82.8%
# - DA10, Dense(1024/1024), lr(5e-5), dropout(0.5) : 84.63%
# - DA10, Dense(1024/1024/1024), lr(5e-5), dropout(0.5) : 84.17%
# - DA10, Dense(4096/4096), lr(5e-5), dropout(0.5): 83.56%
